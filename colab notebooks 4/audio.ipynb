# %%
# !pip install imutils pafy youtube-dl
# !pip install youtube-dl

# %%
# !pip install pafy

# %%
import pafy
import os
import moviepy.editor as mp
url = "https://www.youtube.com/watch?v=ht3yt9_nafw"
video = pafy.new(url)

# %%
bestaudio = video.getbestaudio()
bestaudio.download()

# %%
download_url = input("")
# Out:
# https://www.youtube.com/watch?v=ht3yt9_nafw

# %%
video = pafy.new(download_url)
best = video.streams
file_name = video.streams[0]
file_name
# Out:
# normal:mp4@640x360

# %%
x = file_name.download(filepath= "")

# %%
from google.colab import files

# %%
files.download('/content/القارئ الشيخ رضا عبد المحسن || سورة البقرة.mp4')
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 43482, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 320, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 351, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 364, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 724, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
# ...
