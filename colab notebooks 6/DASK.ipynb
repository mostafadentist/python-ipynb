# %%
# %%html
# <marquee style='width: 50%; color: GOLD;'><b>DASK </b></marquee>
# <marquee style='width: 65%; color: RED;'><b>DASK </b></marquee>
# <marquee style='width: 80%; color: BLUE;'><b>DASK </b></marquee>
# <marquee style='width: 95%; color: green;'><b>DASK </b></marquee>
# Out:
# <marquee style='width: 50%; color: GOLD;'><b>DASK </b></marquee>
# <marquee style='width: 65%; color: RED;'><b>DASK </b></marquee>
# <marquee style='width: 80%; color: BLUE;'><b>DASK </b></marquee>
# <marquee style='width: 95%; color: green;'><b>DASK </b></marquee>

# %%
pip install "dask"

# %%
#import needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import numpy as np
import dask

# %%
#import files to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-901db93d-abf3-4a0e-822f-b1171cb966ea" name="files[]" multiple disabled />
#      <output id="result-901db93d-abf3-4a0e-822f-b1171cb966ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dask_outpatient.csv to dask_outpatient.csv

# %%
import dask.dataframe as dd
>>> df = dd.read_csv('dask_outpatient.csv')
>>> df.head(500000)
# Out:
# /usr/local/lib/python3.6/dist-packages/dask/dataframe/core.py:4553: UserWarning: Insufficient elements for `head`. 500000 elements requested, only 119271 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
#                               Unnamed: 0  ...                             Unnamed: 10
# 0                                    NaN  ...                                     NaN
# 1       ????? ?????? ?????? - ????? - ?2  ...                                     NaN
# 2                           Patient Name  ...                                  Doctor
# 3                  ????? ???? ????? ????  ...  ???? ??? ???? ???????-???? ???? ??????
# 4                  ????? ???? ????? ????  ...  ???? ??? ???? ???????-???? ???? ??????
# ...                                  ...  ...                                     ...
# 119266          ???? ???? ???? ???? ????  ...             ???? ??? ??? ???????- ?????
# ...

# %%
df
# Out:
# Dask DataFrame Structure:
#               Unnamed: 0 Unnamed: 1 Unnamed: 2 ...Outpatient Diagnosis & Sheets... Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# npartitions=1
#                   object     object     object                             float64     object     object     object     object    float64     object      object
#                      ...        ...        ...                                 ...        ...        ...        ...        ...        ...        ...         ...
# Dask Name: from-delayed, 3 tasks

# %%
df.columns = list(df.columns)
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2',
#        '...Outpatient Diagnosis & Sheets...', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')
