# %%
# !pip install fuzzy_pandas
# Out:
# ...
#      |████████████████████████████████| 238 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 83 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 48 kB 4.8 MB/s
# ...
#      |████████████████████████████████| 133 kB 58.0 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 48.0 MB/s
# ...
#      |████████████████████████████████| 46 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 531 kB 68.8 MB/s
# ...
#      |████████████████████████████████| 71 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 155 kB 51.1 MB/s
# ...
#      |████████████████████████████████| 103 kB 71.5 MB/s
# ...
#      |████████████████████████████████| 253 kB 71.8 MB/s
# ...
#      |████████████████████████████████| 251 kB 68.2 MB/s
# ...
#      |████████████████████████████████| 787 kB 70.6 MB/s
# ...
#      |████████████████████████████████| 203 kB 74.5 MB/s
# ...

# %%
#importing dependencies 
import pandas as pd #for spreadsheets
import numpy as np #for numerical values
import fuzzy_pandas as fpd #fuzzy spreadsheets

# %%
df = pd.read_excel('/content/Last sorting count 201.xlsx',sheet_name='Names')

# %%
df.head(5)
# Out:
#                           الاسم NAME1 NAME2  ...   NAME5 NAME6 NAME7
# 0        عمر محمد مصطفى ابراهيم   عمر  محمد  ...     NaN   NaN   NaN
# 1            منه اشرف موسي حامد   منه  اشرف  ...     NaN   NaN   NaN
# 2           احمد حسني علام أحمد  احمد  حسني  ...     NaN   NaN   NaN
# 3                  عمرو عيد جزر  عمرو   عيد  ...     NaN   NaN   NaN
# 4  احمد على ابراهيم محمد المزين  احمد   على  ...  المزين   NaN   NaN
#
# [5 rows x 8 columns]

# %%
df.fillna('')
# Out:
#                             الاسم  NAME1   NAME2  ...   NAME5 NAME6 NAME7
# 0          عمر محمد مصطفى ابراهيم    عمر    محمد  ...
# 1              منه اشرف موسي حامد    منه    اشرف  ...
# 2             احمد حسني علام أحمد   احمد    حسني  ...
# 3                    عمرو عيد جزر   عمرو     عيد  ...
# 4    احمد على ابراهيم محمد المزين   احمد     على  ...  المزين
# ..                            ...    ...     ...  ...     ...   ...   ...
# 197     رشيده مراد سيد عبد الظاهر  رشيده    مراد  ...  الظاهر
# 198        نيفين حمدى السيد الجمل  نيفين    حمدى  ...
# 199              شرين سليمان ربيع   شرين  سليمان  ...
# 200       ميرفت مصطفى ابراهيم على  ميرفت   مصطفى  ...
# 201          امينه مصطفى محمد على  امينه   مصطفى  ...
#
# [202 rows x 8 columns]

# %%
#this code can act as replacer dictionary
#df.replace(to_replace=['Mike', 'Tom', 'Perl'],
#          value= ['Michael', 'Thomas', 'Python'], 
#          inplace=True)
#df

# %%
df2 = pd.read_excel('/content/New Microsoft Excel Worksheet.xlsx',sheet_name='replacers')

# %%
df2
# Out:
#       arabic  english
# 0          1        1
# 1         أ/       a/
# 2    إبراهيد  Ibrahim
# 3    ابراهيم  lbrahim
# 4    إبراهيم  lbrahim
# ..       ...      ...
# 279     وفاء    wafaa
# 280     وليد   Waleed
# 281      يحي    Yahya
# 282     يحيى    Yahia
# 283     يوسف  Youssef
#
# [284 rows x 2 columns]

# %%
# Converting a specific Dataframe column #this is aimed to create a names replacers dictionary
# to list using numpy.ndarray.tolist()
Name_list1 = df2["arabic"].values.tolist() 
print("Converting name to list:") 
# displaying list
Name_list1
str(Name_list1)
# Out:
# Converting name to list:
# ...

# %%
# Converting a specific Dataframe column #this is aimed to create a names replacers dictionary
# to list using numpy.ndarray.tolist()
Name_list2 = df2["english"].values.tolist() 
print("Converting name to list:") 
# displaying list
Name_list2
str(Name_list2)
# Out:
# Converting name to list:
# ...

# %%
# %time
df.replace(to_replace=['1', 'أ/', 'إبراهيد', 'ابراهيم', 'إبراهيم', 'أبراهيم', 'أبو', 'ابو', 'أبوالوفا', 'ابوزيد', 'احمد', 'أحمد', 'ادم', 'اسامه', 'اسعد', 'اسلام', 'إسماعيل', 'اسماعيل', 'أسماعيل', 'اشرف', 'أشرف', 'البسيونى', 'التواب', 'الجزار', 'الجليل', 'الجمل', 'الجواد', 'الجيشى', 'الحافظ', 'الحصرى', 'الحق', 'الحليم', 'الحمد', 'الحميد', 'الحى', 'الخالق', 'الدليل', 'الدهشان', 'الديب', 'الرازق', 'الرجال', 'الرحمن', 'الرحيم', 'الستار', 'السعدى', 'السلام', 'السمرى', 'السيد', 'السيسى', 'الشريف', 'الشناوى', 'الشيال', 'الصاوى', 'الصغير', 'الظاهر', 'العاطي', 'العال', 'العدوى', 'العزيز', 'العمروسى', 'العيسوى', 'الغفار', 'الغنى', 'الغني', 'الفتاح', 'الفتوح', 'الكريم', 'اللاه', 'اللطيف', 'الله', 'الليل', 'المبدى', 'المجيد', 'المصرى', 'المعداوى', 'المعطى', 'المقصود', 'المملوك', 'المنجى', 'المنعم', 'النباش', 'النعيم', 'الواحد', 'الونيس', 'اليزيد', 'امجد', 'امير', 'اميره', 'أمين', 'امين', 'امينه', 'أنور', 'ايمن', 'ايهاب', 'باسل', 'بحيرى', 'بخيت', 'بدر', 'بدوى', 'بسيونى', 'بطرس', 'بكير', 'بلال', 'تامر', 'توفيق', 'تيم', 'جابر', 'جالى', 'جزر', 'جمال', 'جمعه', 'جميل', 'حازم', 'حافظ', 'حامد', 'حجازى', 'حسام', 'حسن', 'حسني', 'حسنين', 'حسين', 'حماده', 'حمدى', 'حميد', 'حنفى', 'خالد', 'خليل', 'خيرى', 'دخيل', 'رأفت', 'رائد', 'ربه', 'ربيع', 'ربيعى', 'رجب', 'رزق', 'رشاد', 'رشوان', 'رشيد', 'رشيده', 'رضا', 'رضوى', 'رفعت', 'رمزي', 'رمضان', 'رودينا', 'رياض', 'زروق', 'زغلول', 'زكريا', 'زياد', 'زيان', 'ساجد', 'ساره', 'سالم', 'سامح', 'سامى', 'سامي', 'سحر', 'سرماح', 'سعد', 'سعديه', 'سعيد', 'سلمى', 'سليمان', 'سمر', 'سمير', 'سند', 'سيد', 'شاش', 'شاهين', 'شحاته', 'شريف', 'شرين', 'شعيشع', 'شفيق', 'شوشن', 'شيبة', 'صابر', 'صالح', 'صباح', 'صديق', 'صفاء', 'صقر', 'صلاح', 'ضيف', 'طاهر', 'طلعت', 'طه', 'عادل', 'عاصم', 'عاطف', 'عاليه', 'عامر', 'عباس', 'عبد', 'عبدالجليل', 'عبدالحميد', 'عبدالرحمن', 'عبدالفتاح', 'عبدالمعبود', 'عبدالناصر', 'عبدالنبى', 'عبده', 'عبدون', 'عبير', 'عثمان', 'عدى', 'عز', 'عسران', 'عصام', 'عطيفى', 'علاء', 'علام', 'على', 'علي', 'عمر', 'عمرو', 'عواد', 'عوض', 'عياد', 'عيد', 'عيسى', 'غازى', 'غزالة', 'فاروق', 'فتحى', 'فراج', 'فرج', 'فرجانى', 'فكرى', 'فهمى', 'فوده', 'فوزى', 'قابيل', 'قاسم', 'قطب', 'كامل', 'كرم', 'كريم', 'كمال', 'لبيب', 'ليديا', 'مبارك', 'متولي', 'مجدى', 'مجدي', 'محروس', 'محمد', 'محمدعبد', 'محمود', 'مراد', 'مرسى', 'مريم', 'مصطفى', 'معاز', 'معوض', 'ملك', 'منصور', 'منه', 'موسي', 'مؤمن', 'مي', 'ميرفت', 'ميمى', 'ناجى', 'ناشد', 'نانسي', 'نبيل', 'نصار', 'نوال', 'نيفين', 'هارون', 'هانى', 'هدى', 'هشام', 'وحيد', 'ورد', 'ورده', 'وفاء', 'وليد', 'يحي', 'يحيى', 'يوسف','عتمان','المزين','هيبه'],
           value= ['1', 'a/', 'Ibrahim', 'lbrahim', 'lbrahim', 'lbrahim', 'Abu', 'Abu', 'Aboulofa', 'Abu Zaid', 'Ahmed', 'Ahmad', 'Adam', 'Ossama', 'asaad', 'Islam', 'Ismael', 'Ismael', 'Ismael', 'Ashraf', 'Ashraf', 'albasiony', 'altawwab', 'algazzar', 'algaleel', 'algamal', 'Jawad', 'algishi', 'Hafez', 'alhosary', 'alhaq', 'alhalim', 'alhamd', 'alhameed', 'alhy', 'alkhaleq', 'aldaleel', 'Duhashan', 'aldeep', 'alrazzak', 'alregal', 'alrahman', 'alraheem', 'alsattar', 'alsaady', 'alsalam', 'alsmry', 'alsayed', 'alsisi', 'alsherief', 'Al Shennawi', 'alshayyal', 'alsawy', 'alsagheer', 'alzaher', 'alaati', 'alaal', 'aladawy', 'alaziz', 'alamrousy', 'alessawi', 'alghaffar', 'alghany', 'alghany', 'alfattah', 'alfotouh', 'alkarim', 'allah', 'allatif', 'Allah', 'alleel', 'almobdy', 'almagid', 'almasry', 'almadaawy', 'almoaty', 'almaqsoud', 'almamlouk', 'almongy', 'almoneam', 'alnabbash', 'alnaem', 'alwahed', 'Alonis', 'alyazid', 'amgd', 'amir', 'amira', 'Ameen', 'ameen', 'amena', 'Anwar', 'Aimen', 'Ehab', 'Basil', 'Bahri', 'Bakheet', 'Badr', 'badawy', 'Basiony', 'botros', 'Bakir', 'Belal', 'tamer', 'tawfik', 'Team', 'Jaber', 'galy', 'gazar', 'gamal', 'gomaa', 'gameel', 'hazem', 'Hafez', 'Hamed', 'Hijazi', 'hossam', 'Hassanein', 'hosny', 'Hassanein', 'Hussain', 'Hamada', 'Hamdy', 'hameed', 'Hanafi', 'Khaled', 'Khalil', 'khairy', 'dukhail', 'Raafat', 'raed', 'raboh', 'rabeah', 'rabeahy', 'rajab', 'risk', 'Rashad', 'Rashwan', 'Rachid', 'rasheda', 'reda', 'Radwa', 'refaat', 'ramzy', 'Ramadan', 'Rodina', 'Riad', 'Zerouk', 'Zaghloul', 'Zakaria', 'ziad', 'ziaan', 'Sajid', 'Sarah', 'salem', 'Sameh', 'Samy', 'samy', 'sahar', 'sermah', 'Saad', 'sadeah', 'saed', 'salma', 'Sulaiman', 'Samar', 'Samir', 'sanad', 'sayed', 'shash', 'Shahin', 'Shehata', 'Sherif', 'Sherine', 'sheasha', 'Shafiq', 'shoshn', 'Cheba', 'Sabir', 'saleh', 'sabah', 'sedeek', 'safaa', 'sakr', 'Salah', 'deef', 'taher', 'Talaat', 'Taha', 'adel', 'Assem', 'Atef', 'alyaa', 'Amer', 'Abbas', 'abd', 'Abd Aljalil', 'Abdul Hamid', 'Abdulrahmman', 'Abdel Fattah', 'Abdulmabood', 'Abdel Naser', 'Abdel Naby', 'abdo ', 'Abdoun', 'abeer', 'Othman', 'Oday', 'ezz', 'asran', 'Essam', 'atefy', 'Alaa', 'allam', 'aly', 'aly', 'omar', 'Amrou', 'Awwad', 'awad', 'Ayad', 'eid', 'eissa', 'ghazy', 'ghazala', 'Farooq', 'Fathi', 'farrag', 'farag', 'Farjani', 'fekry', 'Fahmy', 'Foda', 'Fawzy', 'qabeel', 'Qasim', 'qotb', 'kamel', 'karam', 'kareem', 'kamal', 'labib', 'Lydia', 'mubarak', 'metwally', 'Magdi', 'Magdi', 'mahrous', 'Mohammed', 'Mohammed Abdullah', 'Mahmood', 'morad', 'Morsi', 'Mariam', 'Moustafa', 'moaz', 'Moawad', 'malak', 'Mansoor', 'menna', 'Mousa', 'moamen', 'May', 'Mervat', 'Mimi', 'nagy', 'nashed', 'Nancy', 'Nabil', 'Nasar', 'Nawal', 'Neven', 'haroun', 'Hany', 'hoda', 'Hesham', 'wahid', 'ward', 'warda', 'wafaa', 'Waleed', 'Yahya', 'Yahia', 'Youssef','etman',"elmzayen",'heeba'], 
           inplace=True)
df.head(50)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.96 µs
#                             الاسم  ...                                 New Column Name
# 0          عمر محمد مصطفى ابراهيم  ...      omar Mohammed Moustafa lbrahim nan nan nan
# 1              منه اشرف موسي حامد  ...            menna Ashraf Mousa Hamed nan nan nan
# 2             احمد حسني علام أحمد  ...             Ahmed hosny allam Ahmad nan nan nan
# 3                    عمرو عيد جزر  ...                 Amrou eid gazar nan nan nan nan
# 4    احمد على ابراهيم محمد المزين  ...     Ahmed aly lbrahim Mohammed elmzayen nan nan
# 5               احمد على محمد عمر  ...             Ahmed aly Mohammed omar nan nan nan
# 6          صلاح عبدالناصر محمد طه  ...     Salah Abdel Naser Mohammed Taha nan nan nan
# 7                    محمد الدهشان  ...           Mohammed Duhashan nan nan nan nan nan
# 8         امير فوزى احمد رياض شاش  ...             amir Fawzy Ahmed Riad shash nan nan
# ...

# %%
df.fillna('')
# Out:
#                             الاسم  ...                              New Column Name
# 0          عمر محمد مصطفى ابراهيم  ...   omar Mohammed Moustafa lbrahim nan nan nan
# 1              منه اشرف موسي حامد  ...         menna Ashraf Mousa Hamed nan nan nan
# 2             احمد حسني علام أحمد  ...          Ahmed hosny allam Ahmad nan nan nan
# 3                    عمرو عيد جزر  ...              Amrou eid gazar nan nan nan nan
# 4    احمد على ابراهيم محمد المزين  ...  Ahmed aly lbrahim Mohammed elmzayen nan nan
# ..                            ...  ...                                          ...
# 197     رشيده مراد سيد عبد الظاهر  ...      rasheda morad sayed abd alzaher nan nan
# 198        نيفين حمدى السيد الجمل  ...      Neven Hamdy alsayed algamal nan nan nan
# 199              شرين سليمان ربيع  ...      Sherine Sulaiman rabeah nan nan nan nan
# 200       ميرفت مصطفى ابراهيم على  ...      Mervat Moustafa lbrahim aly nan nan nan
# ...

# %%
df['New Column Name'] = df['NAME1'].map(str).fillna('') + " " + df['NAME2'].map(str).fillna('') + " " + df['NAME3'].map(str).fillna('')  + " " + df['NAME4'].map(str).fillna('') + " " + df['NAME5'].map(str).fillna('') + " " + df['NAME6'].map(str).fillna('') + " " + df['NAME7'].map(str).fillna('')

# %%
df['New Column Name'].head(50).fillna('')
# Out:
# 0         omar Mohammed Moustafa lbrahim nan nan nan
# 1               menna Ashraf Mousa Hamed nan nan nan
# 2                Ahmed hosny allam Ahmad nan nan nan
# 3                    Amrou eid gazar nan nan nan nan
# 4        Ahmed aly lbrahim Mohammed elmzayen nan nan
# 5                Ahmed aly Mohammed omar nan nan nan
# 6        Salah Abdel Naser Mohammed Taha nan nan nan
# 7              Mohammed Duhashan nan nan nan nan nan
# 8                amir Fawzy Ahmed Riad shash nan nan
# 9             rajab kamal abd altawwab Salah nan nan
# 10          Mohammed adel Ahmad Mohammed nan nan nan
# 11          Mohammed Zakaria atefy Ahmed nan nan nan
# 12             Ahmed rajab abd almaqsoud nan nan nan
# 13               Sarah Salah lbrahim nan nan nan nan
# 14            Ahmed Magdi Othman Ahmed abd Allah nan
# 15              Mohammed Hamdy Ahmed aly nan nan nan
# 16     Mohammed mahrous abd alhameed mahrous nan nan
# 17    Mohammed gamal Hanafi Mohammed abd alghany nan
# ...

# %%
df.to_excel(r'/content/1.xlsx', index = False)

# %%
from google.colab import files
files.download('1.xlsx')
