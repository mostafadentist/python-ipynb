# %%
#Loading Dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading The Data Set With Pandas 
dataset = pd.read_excel('/content/h_clustering.xlsx')
dataset.head()
# Out:
#    Patient ID  ... Spending Score (1-100) "How Much They Spend On Cosmotic Supplies"
# 0      112300  ...                                                 39
# 1      112301  ...                                                 81
# 2      112302  ...                                                  6
# 3      112303  ...                                                 77
# 4      112304  ...                                                 40
#
# [5 rows x 5 columns]

# %%
#Gender Is Strongly Related , But Lets Drop It Now For More Simplicity
X = dataset.iloc[:, [3, 4]].values

# %%
import scipy.cluster.hierarchy as sch
dendrogrm = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Patients')
plt.ylabel('Euclidean distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(X)

# %%
# Visualising the clusters
plt.scatter(X[y_hc == 0, 0], X[y_hc == 0, 1], s = 50, c = 'red', label = 'Careful')
plt.scatter(X[y_hc == 1, 0], X[y_hc == 1, 1], s = 50, c = 'blue', label = 'Standard')
plt.scatter(X[y_hc == 2, 0], X[y_hc == 2, 1], s = 50, c = 'green', label = 'Target')
plt.scatter(X[y_hc == 3, 0], X[y_hc == 3, 1], s = 50, c = 'cyan', label = 'Careless')
plt.scatter(X[y_hc == 4, 0], X[y_hc == 4, 1], s = 50, c = 'magenta', label = 'Sensible')
plt.title('Clusters of Patients')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100) Spending On Cosmotics')
plt.legend()
plt.show()
