# %%
#import needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import numpy as np
import seaborn as sn

# %%
#import files to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1d67d5a1-d7d6-4424-8849-9c1347e39ec3" name="files[]" multiple disabled />
#      <output id="result-1d67d5a1-d7d6-4424-8849-9c1347e39ec3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hsb2.csv to hsb2 (1).csv

# %%
for fn in uploaded.keys ():
   print('user upload file "{name}" with length {length} bytes'.format(name=fn,length=len(uploaded[fn])))
# Out:
# user upload file "hsb2.csv" with length 5754 bytes

# %%
uploaded
# Out:
# {'hsb2.csv': b'id,female,race,ses,schtyp,prog,read,write,math,science,socst\r70,0,4,1,1,1,57,52,41,47,57\r121,1,4,2,1,3,68,59,53,63,61\r86,0,4,3,1,1,44,33,54,58,31\r141,0,4,3,1,3,63,44,47,53,56\r172,0,4,2,1,2,47,52,57,53,61\r113,0,4,2,1,2,44,52,51,63,61\r50,0,3,2,1,1,50,59,42,53,61\r11,0,1,2,1,2,34,46,45,39,36\r84,0,4,2,1,1,63,57,54,58,51\r48,0,3,2,1,2,57,55,52,50,51\r75,0,4,2,1,3,60,46,51,53,61\r60,0,4,2,1,2,57,65,51,63,61\r95,0,4,3,1,2,73,60,71,61,71\r104,0,4,3,1,2,54,63,57,55,46\r38,0,3,1,1,2,45,57,50,31,56\r115,0,4,1,1,1,42,49,43,50,56\r76,0,4,3,1,2,47,52,51,50,56\r195,0,4,2,2,1,57,57,60,58,56\r114,0,4,3,1,2,68,65,62,55,61\r85,0,4,2,1,1,55,39,57,53,46\r167,0,4,2,1,1,63,49,35,66,41\r143,0,4,2,1,3,63,63,75,72,66\r41,0,3,2,1,2,50,40,45,55,56\r20,0,1,3,1,2,60,52,57,61,61\r12,0,1,2,1,3,37,44,45,39,46\r53,0,3,2,1,3,34,37,46,39,31\r154,0,4,3,1,2,65,65,66,61,66\r178,0,4,2,2,3,47,57,57,58,46\r196,0,4,3,2,2,44,38,49,39,46\r29,0,2,1,1,1,52,44,49,55,41\r126,0,4,2,1,1,42,31,57,47,51\r103,0,4,
# ...

# %%
import io

# %%
hsb2_df = pd.read_csv("hsb2.csv")

# %%
hsb2_df
# Out:
#       id  female  race  ses  schtyp  prog  read  write  math  science  socst
# 0     70       0     4    1       1     1    57     52    41       47     57
# 1    121       1     4    2       1     3    68     59    53       63     61
# 2     86       0     4    3       1     1    44     33    54       58     31
# 3    141       0     4    3       1     3    63     44    47       53     56
# 4    172       0     4    2       1     2    47     52    57       53     61
# ..   ...     ...   ...  ...     ...   ...   ...    ...   ...      ...    ...
# 195   31       1     2    2       2     1    55     59    52       42     56
# 196  145       1     4    2       1     3    42     46    38       36     46
# 197  187       1     4    2       2     1    57     41    57       55     52
# 198  118       1     4    2       1     1    55     62    58       58     61
# 199  137       1     4    3       1     2    63     65    65       53     61
#
# [200 rows x 11 columns]

# %%
hsb2_df.describe()
# Out:
#                id     female        race  ...        math     science       socst
# count  200.000000  200.00000  200.000000  ...  200.000000  200.000000  200.000000
# mean   100.500000    0.54500    3.430000  ...   52.645000   51.850000   52.405000
# std     57.879185    0.49922    1.039472  ...    9.368448    9.900891   10.735793
# min      1.000000    0.00000    1.000000  ...   33.000000   26.000000   26.000000
# 25%     50.750000    0.00000    3.000000  ...   45.000000   44.000000   46.000000
# 50%    100.500000    1.00000    4.000000  ...   52.000000   53.000000   52.000000
# 75%    150.250000    1.00000    4.000000  ...   59.000000   58.000000   61.000000
# max    200.000000    1.00000    4.000000  ...   75.000000   74.000000   71.000000
#
# [8 rows x 11 columns]

# %%
import pandas as pd
data = pd.read_csv('hsb2.csv')
read = np.array(data['read'])
print(read)
# Out:
# [57 68 44 63 47 44 50 34 63 57 60 57 73 54 45 42 47 57 68 55 63 63 50 60
#  37 34 65 47 44 52 42 76 65 42 52 60 68 65 47 39 47 55 52 42 65 55 50 65
#  47 57 53 39 44 63 73 39 37 42 63 48 50 47 44 34 50 44 60 47 63 50 44 60
#  73 68 55 47 55 68 31 47 63 36 68 63 55 55 52 34 50 55 52 63 68 39 44 50
#  71 63 34 63 68 47 47 63 52 55 60 35 47 71 57 44 65 68 73 36 43 73 52 41
#  60 50 50 47 47 55 50 39 50 34 57 57 68 42 61 76 47 46 39 52 28 42 47 47
#  52 47 50 44 47 45 47 65 43 47 57 68 52 42 42 66 47 57 47 57 52 44 50 39
#  57 57 42 47 42 60 44 63 65 39 50 52 60 44 52 55 50 65 52 47 63 50 42 36
#  50 41 47 55 42 57 55 63]

# %%
print("Mean read:       ", read.mean())
print("Standard deviation read:", read.std())
print("Minimum read:    ", read.min())
print("Maximum read:    ", read.max())
# Out:
# Mean read:        52.23
# Standard deviation read: 10.227272363636358
# Minimum read:     28
# Maximum read:     76

# %%
import seaborn as sns
f, axes = plt.subplots(3, 2, figsize=(10, 10), sharex=True)
sns.distplot( hsb2_df["read"] , color="skyblue", ax=axes[0, 0])
sns.distplot( hsb2_df["write"] , color="olive", ax=axes[0, 1])
sns.distplot( hsb2_df["math"] , color="gold", ax=axes[1, 0])
sns.distplot( hsb2_df["science"] , color="teal", ax=axes[1, 1])
