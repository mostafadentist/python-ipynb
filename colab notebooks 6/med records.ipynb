# %%
# !pip install--upgrade -q gspread
# !pip install gspread-dataframe
# Out:
# ERROR: unknown command "install--upgrade" - maybe you meant "install"
# Collecting gspread-dataframe
#   Downloading https://files.pythonhosted.org/packages/ca/2e/467a7ecf8d0295f39db4826bcdaf837ce2493036fff09026bdd0d252ecef/gspread_dataframe-3.0.2-py2.py3-none-any.whl
# Collecting gspread>=3.0.0 (from gspread-dataframe)
#   Downloading https://files.pythonhosted.org/packages/90/1f/7f919ef5c38ecd64c43fdb8b1b481c14e5651c13d07b2bf5421a7345e119/gspread-3.0.1.tar.gz
# Requirement already satisfied: pandas>=0.14.0 in /usr/local/lib/python2.7/dist-packages (from gspread-dataframe) (0.22.0)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python2.7/dist-packages (from gspread>=3.0.0->gspread-dataframe) (2.18.4)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python2.7/dist-packages (from pandas>=0.14.0->gspread-dataframe) (2018.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python2.7/dist-packages (from pandas>=0.14.0->gspread-dataframe) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from pandas>=0.14.0->gspread-dataframe) (1.14.5)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (2018.8.13)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (3.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python2.7/dist-packages (from python-dateutil->pandas>=0.14.0->gspread-dataframe) (1.11.0)
# Building wheels for collected packages: gspread
# done
#   Stored in directory: /root/.cache/pip/wheels/70/d4/87/c3e549f7548178be1cfb0f46f776919b979fdac98a9d270b5a
# Successfully built gspread
# Installing collected packages: gspread, gspread-dataframe
# Successfully installed gspread-3.0.1 gspread-dataframe-3.0.2

# %%
import numpy as np
import pandas as pd 
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# %%
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
sheet1 = gc.open_by_url('https://docs.google.com/spreadsheets/d/1XU9NrtFW9THnqa-ToPLVntNsONUpfIIG2IuiLVio3lg/edit#gid=1089558816')

# %%
ws = gc.open("World Cup").worksheet("copy of explore example")
existing = gd.get_as_dataframe(ws)
updated = existing.append(your_new_data)
gd.set_with_dataframe(ws, updated)
# Out:
# SpreadsheetNotFoundTraceback (most recent call last)
# <ipython-input-47-2fad9ec93ed4> in <module>()
# ----> 1 ws = gc.open("World Cup").worksheet("copy of explore example")
#       2 existing = gd.get_as_dataframe(ws)
#       3 updated = existing.append(your_new_data)
#       4 gd.set_with_dataframe(ws, updated)
#
# /usr/local/lib/python2.7/dist-packages/gspread/client.pyc in open(self, title)
#     128             return Spreadsheet(self, properties)
#     129         except StopIteration:
# --> 130             raise SpreadsheetNotFound
#     131
#     132     def open_by_key(self, key):
#
# SpreadsheetNotFound:

# %%
from ipywidgets import intslider
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-48-30d698937784> in <module>()
# ----> 1 from ipywidgets import intslider
#
# ImportError: No module named ipywidgets
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import pandas as pd 
import csv
import numpy as np

# %%
# !pip install gspread==2.1.1
# !pip install gspread-dataframe==2.1.0
# !pip install pandas==0.22.0


#import packages and authorize connection to Google account:
import pandas as pd
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.colab import auth
auth.authenticate_user()  # verify your account to read files which you have access to. Make sure you have permission to read the file!
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())
# Out:
# Collecting gspread==2.1.1
#   Downloading https://files.pythonhosted.org/packages/f2/ad/394da65419f6c24b4c4c99a0ade5b7ccfc3eef35ec7433d7b20b534a0f1b/gspread-2.1.1.tar.gz
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python2.7/dist-packages (from gspread==2.1.1) (2.18.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread==2.1.1) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread==2.1.1) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread==2.1.1) (2018.8.13)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread==2.1.1) (3.0.4)
# Building wheels for collected packages: gspread
# done
#   Stored in directory: /root/.cache/pip/wheels/73/69/33/7582e6f6ec819cadbdc94da3ec7766dc2bb79b120e3964c78e
# Successfully built gspread
# gspread-dataframe 3.0.2 has requirement gspread>=3.0.0, but you'll have gspread 2.1.1 which is incompatible.
# Installing collected packages: gspread
#   Found existing installation: gspread 3.0.1
#     Uninstalling gspread-3.0.1:
#       Successfully uninstalled gspread-3.0.1
# Successfully installed gspread-2.1.1
# Collecting gspread-dataframe==2.1.0
#   Downloading https://files.pythonhosted.org/packages/f2/ca/19386116aa52e731fc96a780b458e39a81b544bb9cbb601030ee02450083/gspread_dataframe-2.1.0-py2.py3-none-any.whl
# Requirement already satisfied: pandas>=0.14.0 in /usr/local/lib/python2.7/dist-packages (from gspread-dataframe==2.1.0) (0.22.0)
# Requirement already satisfied: gspread in /usr/local/lib/python2.7/dist-packages (from gspread-dataframe==2.1.0) (2.1.1)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python2.7/dist-packages (from pandas>=0.14.0->gspread-dataframe==2.1.0) (2018.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python2.7/dist-packages (from pandas>=0.14.0->gspread-dataframe==2.1.0) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from pandas>=0.14.0->gspread-dataframe==2.1.0) (1.14.5)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python2.7/dist-packages (from gspread->gspread-dataframe==2.1.0) (2.18.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python2.7/dist-packages (from python-dateutil->pandas>=0.14.0->gspread-dataframe==2.1.0) (1.11.0)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread->gspread-dataframe==2.1.0) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread->gspread-dataframe==2.1.0) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread->gspread-dataframe==2.1.0) (2018.8.13)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests>=2.2.1->gspread->gspread-dataframe==2.1.0) (3.0.4)
# Installing collected packages: gspread-dataframe
#   Found existing installation: gspread-dataframe 3.0.2
#     Uninstalling gspread-dataframe-3.0.2:
#       Successfully uninstalled gspread-dataframe-3.0.2
# Successfully installed gspread-dataframe-2.1.0
# Requirement already satisfied: pandas==0.22.0 in /usr/local/lib/python2.7/dist-packages (0.22.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python2.7/dist-packages (from pandas==0.22.0) (2018.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python2.7/dist-packages (from pandas==0.22.0) (2.5.3)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from pandas==0.22.0) (1.14.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python2.7/dist-packages (from python-dateutil->pandas==0.22.0) (1.11.0)

# %%
import pandas as pd
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from google.colab import auth
auth.authenticate_user()  # verify your account to read files which you have access to. Make sure you have permission to read the file!
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
spreadsheet = gc.open_by_key('1MGAe29YItQDnC4ltBN9Dj55dor_q5JV3ufz_HeofAtI/edit#gid=47383365')
sheet =  spreadsheet.get_worksheet(0)  
df = pd.DataFrame(sheet.get_all_records())
df.head()
# Out:
# APIErrorTraceback (most recent call last)
# <ipython-input-66-a1336b7bac21> in <module>()
#       1 spreadsheet = gc.open_by_key('1MGAe29YItQDnC4ltBN9Dj55dor_q5JV3ufz_HeofAtI/edit#gid=47383365')
# ----> 2 sheet =  spreadsheet.get_worksheet(0)
#       3 df = pd.DataFrame(sheet.get_all_records())
#       4 df.head()
#
# /usr/local/lib/python2.7/dist-packages/gspread/models.pyc in get_worksheet(self, index)
#     139
#     140     def worksheets(self):
# --> 141         """Returns a list of all :class:`worksheets <Worksheet>`
#     142         in a spreadsheet.
#     143
#
# /usr/local/lib/python2.7/dist-packages/gspread/models.pyc in fetch_sheet_metadata(self)
#     121         SubElement(feed, 'gs:colCount').text = str(cols)
#     122
# --> 123         url = construct_url('worksheets', self)
#     124         elem = self.client.post_feed(url, ElementTree.tostring(feed))
#     125
#
# /usr/local/lib/python2.7/dist-packages/gspread/client.pyc in request(self, method, endpoint, params, data, json, files, headers)
#      77         :raises gspread.SpreadsheetNotFound: if no spreadsheet with
#      78                                              specified `title` is found.
# ---> 79
#      80         >>> c = gspread.authorize(credentials)
#      81         >>> c.open('My fancy spreadsheet')
#
# <type 'str'>: (<type 'exceptions.UnicodeEncodeError'>, UnicodeEncodeError('ascii', u'<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 404 (Not Found)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-border-image:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) 0}}@media only screen and (-webkit-min-device-pixel-ratio:2){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat;-webkit-background-size:100% 100%}}#logo{display:inline-block;height:54px;width:150px}\n  </style>\n  <a href=//www.google.com/><span id=logo aria-label=...

# %%
sh = gc.create('medical records')

# %%
# Open our new sheet and read some data.
worksheet = gc.open('medical records').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# APIErrorTraceback (most recent call last)
# <ipython-input-78-16e569ecfd9e> in <module>()
# ----> 1 worksheet = gc.open('medical records').sheet1
#       2
#       3 # get_all_values gives a list of rows.
#       4 rows = worksheet.get_all_values()
#       5 print(rows)
#
# /usr/local/lib/python2.7/dist-packages/gspread/client.pyc in open(self, title)
#     120         :param title: (optional) If specified can be used to filter
#     121                       spreadsheets by title.
# --> 122
#     123         :returns: a list of :class:`~gspread.Spreadsheet` instances.
#     124
#
# /usr/local/lib/python2.7/dist-packages/gspread/client.pyc in list_spreadsheet_files(self)
#      94         """Opens a spreadsheet specified by `key`.
#      95
# ---> 96         :param key: A key of a spreadsheet as it appears in a URL in a browser.
#      97
#      98         :returns: a :class:`~gspread.Spreadsheet` instance.
#
# /usr/local/lib/python2.7/dist-packages/gspread/client.pyc in request(self, method, endpoint, params, data, json, files, headers)
#      77         :raises gspread.SpreadsheetNotFound: if no spreadsheet with
#      78                                              specified `title` is found.
# ---> 79
#      80         >>> c = gspread.authorize(credentials)
#      81         >>> c.open('My fancy spreadsheet')
#
# APIError: {
#  "error": {
#   "errors": [
#    {
#     "domain": "global",
#     "reason": "authError",
#     "message": "Invalid Credentials",
#     "locationType": "header",
#     "location": "Authorization"
#    }
#   ],
#   "code": 401,
#   "message": "Invalid Credentials"
#  }
# }

# %%
pd.pivot_table(df,index=["Name"])
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-73-58c763a32742> in <module>()
# ----> 1 pd.pivot_table(df,index=["Name"])
#
# NameError: name 'df' is not defined
