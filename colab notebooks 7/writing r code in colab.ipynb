# %%
require(googlesheets4)
require(googledrive)
gs_file<- drive_get('medical records')
gs_data <- read_sheet(gs_file)
# Out:
# Loading required package: googlesheets4
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘googlesheets4’”
# Loading required package: googledrive
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘googledrive’”
# Error in drive_get("medical records"): could not find function "drive_get"
# Traceback:
