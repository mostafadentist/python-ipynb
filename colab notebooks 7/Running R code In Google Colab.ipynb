# %%
installed.packages()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6f6ed797d39e> in <module>()
#       1
# ----> 2 installed.packages()
#
# NameError: name 'installed' is not defined
