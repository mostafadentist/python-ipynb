# %%
# !pip install roughviz
# Out:
# Collecting roughviz
#   Downloading roughviz-4.7.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.7/dist-packages (from roughviz) (2.11.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from roughviz) (1.1.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2->roughviz) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->roughviz) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->roughviz) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas->roughviz) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->roughviz) (1.15.0)
# Installing collected packages: roughviz
# Successfully installed roughviz-4.7.0

# %%
import roughviz
import pandas as pd

# %%
df = pd.read_excel('/content/Data For Roughviz.xlsx')
df
# Out:
#     Month  Hospital A Revenue  Hospital B Revenue
# 0     JAN             1100000             1110000
# 1     FEB             1125000             1125000
# 2  MARCH              1150000             1260000

# %%
roughviz.bar(df["Month"], df["Hospital A Revenue"], axisRoughness = 0.3, axisStrokeWidth = 0.4, roughness=1.3, highlight="green")
# Out:
# <html>
# <body>
#
# <div id="hdpswxwhpf"></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.Bar(
#   {
#     element: "#".concat("hdpswxwhpf"),
#     data: {
#       labels: ['JAN', 'FEB', 'MARCH '],
#       values: [1100000, 1125000, 1150000]
#     },
# 	axisFontSize: "1.5rem",
# 	axisRoughness: 0.3,
# 	axisStrokeWidth: 0.4,
# 	bowing: 0,
# 	color: "skyblue",
# 	fillStyle: "cross-hatch",
# 	fillWeight: 0,
# 	font: 0,
# 	highlight: "green",
# 	innerStrokeWidth: 0,
# 	labelFontSize: "2rem",
# 	padding: 0.1,
# 	roughness: 1.3,
# 	simplification: 0.2,
# 	stroke: "black",
# 	strokeWidth: 1,
# 	title: "",
# 	titleFontSize: "3rem",
# 	tooltipFontSize: "3rem",
# 	xLabel: "",
# 	yLabel: "",
# 	height: 400,
# 	width: 700,
# 	interactive: true
#   }
# );
# 	var text = document.querySelectorAll(".xAxishdpswxwhpf .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("hdpswxwhpf").style.height = "380px";
# 	document.querySelector("#hdpswxwhpf svg").style.height = "380px";
# });
# </script>
#
# </body>
# </html>

# %%
roughviz.barh(df["Month"], df["Hospital B Revenue"], axisRoughness = 0.1, axisStrokeWidth = 20.7, roughness=2.3, highlight="gray")
# Out:
# <html>
# <body>
#
# <div id="yuyzidiljg"></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.BarH(
#   {
#     element: "#".concat("yuyzidiljg"),
#     data: {
#       labels: ['JAN', 'FEB', 'MARCH '],
#       values: [1110000, 1125000, 1260000]
#     },
# 	axisFontSize: "1.5rem",
# 	axisRoughness: 0.1,
# 	axisStrokeWidth: 20.7,
# 	bowing: 0,
# 	color: "skyblue",
# 	fillStyle: "cross-hatch",
# 	fillWeight: 0,
# 	font: 0,
# 	highlight: "gray",
# 	innerStrokeWidth: 0,
# 	labelFontSize: "2rem",
# 	padding: 0.1,
# 	roughness: 2.3,
# 	simplification: 0.2,
# 	stroke: "black",
# 	strokeWidth: 1,
# 	title: "",
# 	titleFontSize: "3rem",
# 	tooltipFontSize: "3rem",
# 	xLabel: "",
# 	yLabel: "",
# 	height: 400,
# 	width: 700,
# 	interactive: true
#   }
# );
# 	var text = document.querySelectorAll(".xAxisyuyzidiljg .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("yuyzidiljg").style.height = "380px";
# 	document.querySelector("#yuyzidiljg svg").style.height = "380px";
# });
# </script>
#
# </body>
# </html>

# %%
roughviz.pie(df["Month"], df["Hospital B Revenue"], axisRoughness = 0.7, axisStrokeWidth = 0.7, roughness=10.3, highlight="gray")
# Out:
# <html>
# <body>
#
# <div id="iwqstwomhj"></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.Pie(
#   {
#     element: "#".concat("iwqstwomhj"),
#     data: {
#       labels: ['JAN', 'FEB', 'MARCH '],
#       values: [1110000, 1125000, 1260000]
#     },
# 	bowing: 0,
# 	fillStyle: "cross-hatch",
# 	fillWeight: 0,
# 	font: 0,
# 	highlight: "gray",
# 	innerStrokeWidth: 0,
# 	margin: {top: 50, right: 20, bottom: 70, left: 100},
# 	roughness: 10.3,
# 	simplification: 0.2,
# 	strokeWidth: 1,
# 	title: "",
# 	titleFontSize: "3rem",
# 	tooltipFontSize: "3rem",
# 	interactive: true
#   }
# );
# 	var text = document.querySelectorAll(".xAxisiwqstwomhj .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("iwqstwomhj").style.height = "380px";
# 	document.querySelector("#iwqstwomhj svg").style.height = "380px";
# });
# </script>
#
# </body>
# </html>

# %%
roughviz.donut(df["Month"], df["Hospital B Revenue"], axisRoughness = 0.7, axisStrokeWidth = 0.7, roughness=2.3, highlight="gray")
# Out:
# <html>
# <body>
#
# <div id="unmayihxqq"></div>
#
# <script src="https://requirejs.org/docs/release/2.3.6/minified/require.js"></script>
# <script>
# require.config({paths: {roughViz: "https://unpkg.com/rough-viz@1.0.5/dist/roughviz.min"}});
# require(["roughViz"], function(roughViz) {
#
# new roughViz.Donut(
#   {
#     element: "#".concat("unmayihxqq"),
#     data: {
#       labels: ['JAN', 'FEB', 'MARCH '],
#       values: [1110000, 1125000, 1260000]
#     },
# 	bowing: 0,
# 	fillStyle: "cross-hatch",
# 	fillWeight: 0,
# 	font: 0,
# 	highlight: "gray",
# 	innerStrokeWidth: 0,
# 	roughness: 2.3,
# 	simplification: 0.2,
# 	strokeWidth: 1,
# 	title: "",
# 	titleFontSize: "3rem",
# 	tooltipFontSize: "3rem",
# 	interactive: true
#   }
# );
# 	var text = document.querySelectorAll(".xAxisunmayihxqq .tick text");
# 	var i;
# 	for (i = 0; i < text.length; i++) {
# 		text[i].setAttribute("transform", "rotate(0)");
# 		text[i].style.textAnchor="middle";
# 	}
# 	document.getElementById("unmayihxqq").style.height = "380px";
# 	document.querySelector("#unmayihxqq svg").style.height = "380px";
# });
# </script>
#
# </body>
# </html>
