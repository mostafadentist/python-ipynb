# %%
# !pip install google google_translator
# !pip install --upgrade pip
# !pip install --upgrade google-api-python-client
# !pip install google_trans_new
# !pip install googletrans
# !pip install fuzzy-pandas 
# !pip install googletrans==4.0.0-rc1

# %%
#importing dependencies
from googletrans import Translator
import pandas as pd #for spreadsheets
import numpy as np #for numerical values
import fuzzy_pandas as fpd #fuzzy spreadsheets
import re #regular expressions

# %%
translator = Translator(service_urls=[
      'translate.google.com',
    ])

# %%
translator = Translator()

# %%
df1 = pd.read_excel('/content/Last sorting count 201.xlsx',sheet_name='Alex')

# %%
df1
# Out:
#     Column1  ...   Work Location
# 0    1807.0  ...           Galaa
# 1    3007.0  ...           Galaa
# 2    2904.0  ...           Galaa
# 3    2802.0  ...           Galaa
# 4    2708.0  ...           Galaa
# ..      ...  ...             ...
# 76   4051.0  ...  Nubareya (MSF)
# 77   4052.0  ...  Nubareya (MSF)
# 78      NaN  ...  Nubareya Store
# 79      NaN  ...  Nubareya Store
# 80      NaN  ...  Nubareya Store
#
# [81 rows x 4 columns]

# %%
# Converting a specific Dataframe column
# to list using numpy.ndarray.tolist()
Name_list = df1["Employee Name in English"].values.tolist() 
print("Converting name to list:") 
# displaying list
Name_list
# Out:
# Converting name to list:
# ['Wahid Shafik Gomaa',
#  'Osama Mahmoud Youssef',
#  'Abdel Hamid El Sayed Abdel Hamid',
#  'El Sayed Saeed Saad Sherif',
#  'Rabea Bekheet Ismail',
#  'Ahmed Abdullah Ghazy',
#  'Ashraf Abdel Hamid Abdel Fattah',
#  'Ahmed Mohamed El Saghyr',
#  'Ehab Abdel Hamid El Sherif',
#  'Gomaa Mahmoud Abdel Galeel',
#  'Mohamed Abdel Aziz Ibrahim',
#  'Ibrahim Zaghlol Mohamed Ali',
#  'Gamal Abdel Hamid Al Sherif',
#  'Ayman Mohamed Mohamed El Deeb',
#  'El Sayed Mahmoud Mansour',
#  'Omar Abdel Aziz Ibrahim',
#  'Mohamed Ibrahim Abu El Wafa',
#  'Ali Ahmed Ezz Al Regal',
#  'Ayman Ali Abu Warda',
#  'Amgad Mahmoud Youssef',
#  'Mohamed El Sayed Ahmed Ghazy',
#  'Mimi Ibrahim Mostafa',
#  'Abdo Zidan Farag',
#  'Saad Mohamed Ali Mamlouk ',
#  'Mohamed Seddik Mohamed Hussein',
#  'Ahmed Mahmoud Mohamed Abdel Salam',
#  'Mahmoud Abdel Geleel Gaber',
#  'Khalil Saber Ali Ahmed',
#  'Hassan Ali Khalil ',
#  'Sameh Ahmed Abdel Maksoud',
#  'Mohamed Mahmoud Abdel Latif Etman',
#  'Mahmoud Ibrahim Abdel Fattah El Semary',
#  'Ashraf Mahmoud Hamed',
#  'Hany Awad Abdel Ghani',
#  'Ahmed Abdel Aziz Mahmoud El Shennawy',
#  'Ali Deif Mubarak',
#  'Hussein Salem Abdel Ghani Hussein',
#  'Mahmoud Farag Ibrahim',
#  'Mohamed Adel Ahmed Mohamed',
#  'Saeed Kamal Abdel Tawab',
#  'Hassan Saeed Abdel Megeed',
#  'Assem Mahmoud Abdel Hamid',
#  'Mohamed Abdel Sattar Abdel Hamid',
#  'Gamal Anwar Shehata',
#  'Ahmed Mahmoud Metwally',
#  'Shoshan Abdel Wanis Shoshan',
#  'Hani Anwar Ibrahim',
#  'Yehia Ibrahim Abdel Fattah',
#  'Hussein Ali Hussein',
#  'Saber Ragab Saber',
#  'Mohamed Mohamed Abo El Yazyd',
#  'Ibrahim Abdel Reheem',
#  'Reda Ahmed Abdel Tawab',
#  'Hamada Hamid Zarouk',
#  'Gamal Ahmed Mohamed Ibrahim',
#  'Ahmed Mahmoud Ibrahim Abdel Razik',
#  'Mohamed Hussein Abdel Gawad',
#  'Mahmoud Ali Mahmoud Abdel Naeem',
#  'Mohamed Haroun Dakhil',
#  'Abdel Sattar Farag Sermah Karim',
#  'Ramadan Rizk Abd Rabou',
#  'Mansour Farag Sermah Karim ',
#  'Mostafa Mohamed Abdel Rahman',
#  'Rabeay Ahmed Abdel Tawab Salah',
#  'Amr Ahmed Mohamed El Shayal',
#  'Essam Abdel Gawad Abdel Aaty Ismail',
#  'Ragab Kamal Abdel Tawab Salah',
#  'Ahmed Hosny Allam',
#  'Ahmed Magdy Othman',
#  'Salah Abdel Nasser Mohamed',
#  'Samy Abdullah Soliman',
#  'Eslam Abdel Aziz Mostafa',
#  'Hassan Shehata Amin',
#  'Ahmed Mohamed Ahmed Moawaad',
#  'Hussein Ali Deif',
#  'Mohamed Abdel Aal Nassar',
#  'Mohamed El Dahshan',
#  'Mohamed Ali Khalil Ward',
#  'Mostafa Mahmoud El Sayed Badr',
#  'Mohamed Gamal Hanafy Abdel Ghany',
#  'Ahmed Ali Ibrahim Mohamed El Mezayen']

# %%
# %%capture
# !pip install git+https://github.com/neuml/txtai#egg=txtai[pipeline]

# %%
# %%capture
from txtai.pipeline import Translation
# Create translation model
translate = Translation()

# %%
translation = translate(Name_list, "ar")
translation
# Out:
# Downloading:   0%|          | 0.00/916k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.80G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.54M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/272 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/294M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/805k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/293M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/812k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/901k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.08M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/294M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/827k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/876k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.13M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/294M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/810k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/882k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/293M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/807k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/903k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.09M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/293M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/782k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/895k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.02M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# ['واهيد شافيك غوميا',
#  'أوساما محمود يوسف',
#  'عبد الحميد عبد الحميد',
#  'الشيخ صالح صالح صالح صالح صالح صالح صالح صالح',
#  '(رابا بكهيت إيسميل)',
#  '1 أحمد عبد الله',
#  '(آشراف عبد الحميد عبد الفتاح)',
#  'محمد محمد محمد الطغرير',
#  '3 - عرب عبد الحسن حميد الشريف الشريف',
#  'غوميا محمود عبد الجليل',
#  '1/ محمد محمد عبد العزيز',
#  'ابراهيم زغلاويل محمد علي علي علي',
#  '٢ - جمال جمال جمال عبد بن بن بن الشريف الشريف الشريف',
#  '١ - أيمن محمد محمد محمد الديب',
#  'كلمات متعلقة Sayed Mahmoud Mansour',
#  'محمد عمر عمر عمر عبد العزيز',
#  '4 - محمد محمد محمد محمد محمد مصطفى مصطفى مصطفى أبو صف صف صف صفا',
#  '2 - علي عودة البسط',
#  'علمان علي علي',
#  'أمغاد محمود يوسف',
#  'محمد الحسن أحمد غازي',
#  'منيي إبراهيم مصطفى',
#  'زيدان زيدان',
#  'محمد محمد علي المملوك',
#  'محمد سيدديك محمد حسين',
#  'أحمد محمد محمد محمد محمد',
#  '(محمود عبد الله جيليل جابر)',
#  'خليل الصابر علي أحمد',
#  '',
#  'سامح أحمد عبد المهدي',
#  '(محمد محمود عبدالرحمن)',
#  '2 - محمود إبراهيم إبراهيم مصطفى فتح فتحة السمري',
#  '1//////////////////////////////////////',
#  'الهاني عواد عبد الغماني',
#  '3 - أحمد عبد العزيز عبد العزيز محمود السناوي',
#  'علي ديف مبارك',
#  '1 - حسين سليم عبد المحفوظ',
#  '-حماد إبراهيم) )',
#  'محمد عبد الواحد أحمد محمد محمد محمد محمد',
#  'المُسَبْلْكَيْن مُنْقِش',
#  'حسن سعيد عبد المهدي',
#  '2 - استســم أسســم محمود عبد الحمد',
#  'محمد عبد الحميد عبد الحميد',
#  'لعبة Anwar Shehata',
#  '(أحمد ميتوالي)',
#  '6 - شوشان عبد الناصر',
#  'هاني أن إبراهيم',
#  'يهيا إبراهيم عبد الفتاح',
#  'حسين علي علي علي',
#  '(سابر راغر سابر)',
#  '4 - محمد محمد محمد محمد محمد محمد محمد أبو أبو أبو الزيد',
#  'إبراهيم إبراهيم عبد الرحيم',
#  '(رداء عبد الله تاوآب)',
#  '2 - حمد حمد حمد حميد سكرق',
#  'جمال أحمد محمد إبراهيم',
#  'أحمد محمود محمود',
#  'محمد محمد محمد محمد عبد الغافاد',
#  'محمود علي علي علي محمود عبد النعم',
#  'محمد حارون دخيل',
#  'عبد العزيز ساتار فاراغ سيرماخ كريم',
#  'رمضضضان الرصصص',
#  '(منـاورة (حـارمـة',
#  'مصطفى محمد محمد عبد الرحمن',
#  'رابي أحمد عبد العزيز خطأ',
#  '- عمر عمر عمر عمر عمرر أحمد محمد محمد الشعيال',
#  'السيد عصام عبد عبد القاعد عبد العتي',
#  'راغاب كامال عبد العزيز خطأ',
#  '(أحمد حسيني عولم)',
#  'أحمد ماجدي عثمان',
#  'عبد الناصر محمد',
#  'مايي سامي عبد الله سليمان',
#  'أسلم عبد اللطيف',
#  'حسن شهيتا أمين',
#  'أحمد محمد محمد محمد محمد',
#  '(حسين علي ديف)',
#  'محمد محمد عبد العلم',
#  'محمد الدوشان',
#  'محمد علي علي خليل',
#  'موستافا محمود البادري',
#  'محمد جمال حنافي عبد الغني',
#  '2 - أحمد علي محمد إبراهيم إبراهيم إبراهيم محمد المزيين']

# %%
df = pd.DataFrame(translation)
df.head(210)
# Out:
#                                                     0
# 0                                   واهيد شافيك غوميا
# 1                                   أوساما محمود يوسف
# 2                               عبد الحميد عبد الحميد
# 3       الشيخ صالح صالح صالح صالح صالح صالح صالح صالح
# 4                                 (رابا بكهيت إيسميل)
# ..                                                ...
# 76                                       محمد الدوشان
# 77                                  محمد علي علي خليل
# 78                              موستافا محمود البادري
# 79                          محمد جمال حنافي عبد الغني
# 80  2 - أحمد علي محمد إبراهيم إبراهيم إبراهيم محمد...
#
# [81 rows x 1 columns]
