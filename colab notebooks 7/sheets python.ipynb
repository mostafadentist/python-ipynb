# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': 'xyz'.split(),
                   'B': 'xyz'.split(),
                   'C': np.arange(8), 'D': np.arange(8) * 2})
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-825ab3ca4887> in <module>()
#       3 df = pd.DataFrame({'A': 'xyz'.split(),
#       4                    'B': 'xyz'.split(),
# ----> 5                    'C': np.arange(8), 'D': np.arange(8) * 2})
#       6 print(df)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      49     # figure out the index, if necessary
#      50     if index is None:
# ---> 51         index = extract_index(arrays)
#      52     else:
#      53         index = ensure_index(index)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in extract_index(data)
#     315             lengths = list(set(raw_lengths))
#     316             if len(lengths) > 1:
# --> 317                 raise ValueError('arrays must all be same length')
#     318
#     319             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# !pip install --upgrade -q gspread
# !pip install  gspread-dataframe
# Out:
# Requirement already satisfied: gspread-dataframe in /usr/local/lib/python3.6/dist-packages (3.0.2)
# Requirement already satisfied: gspread>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from gspread-dataframe) (3.1.0)
# Requirement already satisfied: pandas>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from gspread-dataframe) (0.22.0)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.6/dist-packages (from gspread>=3.0.0->gspread-dataframe) (2.18.4)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.14.0->gspread-dataframe) (1.14.6)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.14.0->gspread-dataframe) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.14.0->gspread-dataframe) (2.5.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (2018.11.29)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.2.1->gspread>=3.0.0->gspread-dataframe) (2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas>=0.14.0->gspread-dataframe) (1.11.0)

# %%
import numpy as np
import pandas as pd
import gspread 
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
# Open our new sheet and read some data.
worksheet = gc.open('vlookup').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
df=pd.DataFrame.from_records(rows)
# Out:
# [['Staff_Name', 'Company Name', 'COMPANY FREQUENCY', 'PID', 'Patient Name', 'number of patient admissions', 'Patient Sex', 'male count', 'female count', 'Age', 'age moments', '', 'values', 'Pat Phone1', 'Pat Phone2', 'Bed No', 'Doctor Name', 'dr freq', 'frequent doctors', 'Specialty', 'frequent speciality', 'Diagnosis Code', 'diagnosis', '', '', '', '', '', '', 'diagnosis', '', 'Admission Diagnoses', 'diagnosis on admission', 'Arrive Type', 'common arrive type', 'Admision Date', 'Admision Time', 'Actual Dis Date', 'Discharge Time', '', '592.1', '3.222222222', '', 'Discharge Status', 'ranking discharge status', 'Fin_Type', 'common fin type', 'Patient Source', 'common patient source'], ['RADWA ABDO ABDELAZIZ HAMADA', 'جامعة الدول العربية - اجل', '3', '100519', 'SOILAHOUDINE HOUSSAMDINE CHELKH SAADI', '1', 'ذكر', '329', '240', '4', 'mean', '37.64674868', '37.64674868', '1156259011', '', '501/3 حالة نهارية', 'محمد عاصم الفقى - جراحه اطفال', '8', '8', 'جراحه اطفال', '8', '750', 'TONGUE TIE', '', '', '750', 'TONGUE TIE', '', '', 'TONGUE TIE', '', 'فك التصاق بالسان', '3', 'AL-MAADI CLINICS', '304', '5/18/2018', '2:43:05 PM', '5/18/2018', '7:34:13 PM', '0', '280.9', '5.6', '', 'IMPROVED', '512', 'حالات شركات', '419', 'شركات متعاقده مع المستشفى', '315'], ['RADWA ABDO ABDELAZIZ HAMADA', 'جامعة الدول العربية - اجل', '3', '100520', 'ANLAOUDINE HOUSSAMDINE CHELKH SAANDI', '1', 'ذكر', '', '', '6', 'mode', '34', '34', '1156259011', '', '501/2 حالة نهارية', 'محمد عاصم الفقى - جراحه اطفال', '8', '8', 'جراحه اطفال', '8', '750', 'TONGUE TIE', '', '', '750', 'TONGUE TIE', '', '', 'TONGUE TIE', '', 'فك التصاق بالسان', '3', 'AL-MAADI CLINICS', '304', '5/18/2018', '2:34:55 PM', '5/18/2018', '7:33:55 PM', '0', '535', '1', '', 'IMPROVED', '512', 'حالات شركات', '419', 'شركات متعاقده مع المستشفى', '315'], ['RADWA ABDO ABDELAZIZ HAMADA', 'جلوب ميد - اجل', '34', '101402', 'ادم محمد محمد توفيق', '1', 'ذكر', '', '', '3', 'standard deviation', '', '21.22415564', '1211910018', '1124770022', 'اولى مفرده 402/1', 'محمد عاصم الفقى - جراحه اطفال', '8', '8', 'جراحه اطفال', '8', '246.2', 'CYST OF THYROID', '', '', '750', 'TONGUE TIE', '', '', 'CYST OF THYROID', '', 'استئصال كيس درقى', '1', 'AL-MAADI CLINICS', '304', '5/24/2018', '1:07:06 PM', '5/24/2018', '10:51:57 PM', '0', '540.9', '3.75', '', 'IMPROVED', '512', 'حالات شركات', '419', 'شركات متعاقده مع المستشفى', '315'], ['AHMED MEDHAT MOUSTAFA AHMED', 'جلوب ميد - اجل', '34', '10143', 'احمد محمد احمد ابراهيم', '1', 'ذكر', '', '', '32', 'min', '', '0', '1006060961', '1114271424', 'اولى مفرده مميزه 608/1', 'هانى سعيد عبد الباسط - جراحه', '7', '7', 'الجراحه العامه', '97', '565', 'ANAL FISSURE', '', '', '246.2', 'CYST OF THYROID', '', '', 'ANAL FISSURE', '', 'بواسير شرجيه - شرخ شرجى - فحص تحت مخدر', '1', 'AL-MAADI CLINICS', '304', '5/6/2018', '6:58:59 PM', '5/7/2018', '12:34:34 PM', '1', '474.02', '0.25', '', 'IMPROVED', '512', 'حالات شركات', '419', 'منطقة السكن', '25'], ['AMIRA ABDELKARIM HASSAN', 'نكست كير للرعاية الصحية - اجل', '16', '10148', 'انتصار قطب عبدالجواد مصطفى', '1', 'انثى', '', '', '44', 'max', '', '91', '1061118292', '1227076900', '501/1 حالة نهارية', 'احمد فتحى عبد الفتاح هلال- هضمى وكبد ومناظير', '27', '27', 'امراض باطنه', '115', '', '', '', '', '565', 'ANAL FISSURE', '', '', '', '', 'منظار معده + منظار قولون+عينه', '1', 'AL-MAADI CLINICS', '304', '5/13/2018', '2:19:58 PM', '5/13/2018', '7:55:36 PM', '0', '789', '2.4', '', 'IMPROVED', '512', 'حالات شركات', '419', 'شركات متعاقده مع المستشفى', '315'], ['AMIRA ABDELKARIM HASSAN', 'اليكو - اجل', '96', '10216', 'محمود رشاد محمود حسين', '1', 'ذكر', '', '', '41', 'median', '', '36', '1019408097', '1142049931', 'رعاية القلب/10', 'هيثم عبد الفتاح مطاوع بدران - قلب', '14', '14', 'امراض القلب', '102', '410.9', 'ACUTE MYOCARDIAL INFARCTION, UNSPECIFIED SITE, EPISODE OF CARE UNSPECIFIED', '', '', '', '#N/A', '', '', 'ACUTE MYOCARDIAL INFARCTION, UNSPECIFIED SITE, EPISODE OF CARE UNSPECIFIED', '', 'اشتباه جلطه حديثه بالقلب', '1', 'EMERGENCY', '176', '5/19/2018', '9: ...

# %%
df
# Out:
#                               0                                           1   \
# 0                     Staff_Name                                Company Name
# 1    RADWA ABDO ABDELAZIZ HAMADA                   جامعة الدول العربية - اجل
# 2    RADWA ABDO ABDELAZIZ HAMADA                   جامعة الدول العربية - اجل
# 3    RADWA ABDO ABDELAZIZ HAMADA                              جلوب ميد - اجل
# 4    AHMED MEDHAT MOUSTAFA AHMED                              جلوب ميد - اجل
# 5        AMIRA ABDELKARIM HASSAN               نكست كير للرعاية الصحية - اجل
# 6        AMIRA ABDELKARIM HASSAN                                 اليكو - اجل
# 7       MOHAMED AHMED ASEM ABBAS                                 اليكو - اجل
# 8        AMIRA ABDELKARIM HASSAN                               بتروجلف - اجل
# 9       MOHAMED AHMED ASEM ABBAS                               بتروجلف - اجل
# 10             ALI MOHAMED AFIFI                                 اليكو - اجل
# 11       AMIRA ABDELKARIM HASSAN                              يونى كير - اجل
# 12       AMIRA ABDELKARIM HASSAN                          اكسا للتأمين - اجل
# 13   AHMED MEDHAT MOUSTAFA AHMED                              جلوب ميد - اجل
# 14   AHMED MEDHAT MOUSTAFA AHMED                                 اليكو - اجل
# 15       AMIRA ABDELKARIM HASSAN                                 اليكو - اجل
# 16      MOHAMED AHMED ASEM ABBAS
# 17       AMIRA ABDELKARIM HASSAN                          رشيد للبترول - اجل
# 18       AMIRA ABDELKARIM HASSAN
# 19   RADWA ABDO ABDELAZIZ HAMADA                              يونى كير - اجل
# 20   AHMED MEDHAT MOUSTAFA AHMED
# 21      MOHAMED AHMED ASEM ABBAS                              يونى كير - اجل
# 22       AMIRA ABDELKARIM HASSAN                                 اليكو - اجل
# 23   RADWA ABDO ABDELAZIZ HAMADA                      كير بلاس للرعاية - اجل
# 24   RADWA ABDO ABDELAZIZ HAMADA                                 اليكو - اجل
# 25   RADWA ABDO ABDELAZIZ HAMADA  مجموعة شركات منصور للتجارة و التوزيع - اجل
# 26   AHMED MEDHAT MOUSTAFA AHMED
# 27   AHMED MEDHAT MOUSTAFA AHMED                              يونى كير - اجل
# 28   AHMED MEDHAT MOUSTAFA AHMED
# 29   AHMED MEDHAT MOUSTAFA AHMED                       ميدرايت للتامين - اجل
# ..                           ...                                         ...
# 540      AMIRA ABDELKARIM HASSAN                              جلوب ميد - اجل
# 541     MOHAMED AHMED ASEM ABBAS                         الماسية - اجل D.M.S
# 542     MOHAMED AHMED ASEM ABBAS                            شركة ميدنت - اجل
# 543      AMIRA ABDELKARIM HASSAN                                 اليكو - اجل
# 544      AMIRA ABDELKARIM HASSAN                              بتروسلام - اجل
# 545      AMIRA ABDELKARIM HASSAN                                 اليكو - اجل
# 546            ALI MOHAMED AFIFI                                 اليكو - اجل
# 547  RADWA ABDO ABDELAZIZ HAMADA                                 اليكو - اجل
# 548  AHMED MEDHAT MOUSTAFA AHMED                                  بوبا - اجل
# 549  RADWA ABDO ABDELAZIZ HAMADA                          اكسا للتأمين - اجل
# 550            ALI MOHAMED AFIFI                          اكسا للتأمين - اجل
# 551            ALI MOHAMED AFIFI
# 552            ALI MOHAMED AFIFI
# 553  AHMED MEDHAT MOUSTAFA AHMED                      الاهلى للمشروعات - اجل
# 554     MOHAMED AHMED ASEM ABBAS
# 555     MOHAMED AHMED ASEM ABBAS                                 اليكو - اجل
# 556      AMIRA ABDELKARIM HASSAN                            برايم هيلث - اجل
# 557     MOHAMED AHMED ASEM ABBAS                              يونى كير - اجل
# 558  AHMED MEDHAT MOUSTAFA AHMED                            برايم هيلث - اجل
# 559      AMIRA ABDELKARIM HASSAN               ميدى كير للرعاية الصحية - اجل
# 560     MOHAMED AHMED ASEM ABBAS                       التعاون للبترول - اجل
# 561     MOHAMED AHMED ASEM ABBAS                              يونى كير - اجل
# 562     MOHAMED AHMED ASEM ABBAS                              جلوب ميد - اجل
# 563  RADWA ABDO ABDELAZIZ HAMADA                       ميدرايت للتامين - اجل
# 564  AHMED MEDHAT MOUSTAFA AHMED                                 اليكو - اجل
# 565  AHMED MEDHAT MOUSTAFA AHMED                       ميدرايت للتامين - اجل
# 566  RADWA ABDO ABDELAZIZ HAMADA                            برايم هيلث - اجل
# 567      AMIRA ABDELKARIM HASSAN                              يونى كير - اجل
# 568     MOHAMED AHMED ASEM ABBAS                              يونى كير - اجل
# 569  RADWA ABDO ABDELAZIZ HAMADA                              دانه غاز - اجل
#
#                     2       3                                      4   \
# 0    COMPANY FREQUENCY     PID                           Patient Name
# 1                    3  100519  SOILAHOUDINE HOUSSAMDINE CHELKH SAADI
# 2                    3  100520   ANLAOUDINE HOUSSAMDINE CHELKH SAANDI
# 3                   34  101402                    ادم محمد محمد توفيق
# 4                   34   10143                 احمد محمد احمد ابراهيم
# 5                   16   10148             انتصار قطب عبدالجواد مصطفى
# 6                   96   10216                  محمود رشاد محمود حسين
# 7                   96  102376                  نيفين سمير محمد توفيق
# 8                    2   10238          ابراهيم عبدالنبى ابراهيم احمد
# 9                    2   10238          ابراهيم عبدالنبى ابراهيم احمد
# 10                  96  102828           وائل ابراهيم الدسوقى ابراهيم
# 11                  25  103906                  محمد سمير عليوه محمود
# 12                  25  104339                اسماء ماهر ابراهيم ثابت
# 13                  34   10442                 هاله خالد حسن عبدالنبى
# 14                  96   10660                    نيره احمد جابر احمد
# 15                  96  106834                    عماد محمد حافظ عطيه
# 16                   0   10800                   جيهان عثمان على احمد
# 17                   3  109356                    امين خليل محمد خليل
# 18                   0  109475              لمياء احمد عبدالعزيز دوسه
# 19                  25  109862                    مالك هيثم محمد محمد
# 20                   0  112495                   ايمان احمد احمد احمد
# 21                  25   11325                    شيماء محمد حسن جمعه
# 22                  96  113361               محمد محمد نور الدين محمد
# 23                   8  113379                   حبيبه معتز احمد محمد
# 24                  96   11451              محمد رمضان ابو الحسن حسين
# 25                   3  114985             سامى محمود ابراهيم ابراهيم
# 26                   0  115364                     امل مدحت رمضان على
# 27                  25  116451                   محمد اشرف محمد زهران
# 28                   0  116924                     احمد محمد مراد على
# 29                  29  118282              لبنى محمد صلاح الدين محمد
# ..                 ...     ...                                    ...
# 540                 34   78119                ريتاج ماجد ابراهيم محمد
# 541                 10   78234            عمار عماد احمد ابراهيم محمد
# 542                 14   78998         عبير عبدالحى عبدالرسول عبدالله
# 543                 96   79355               مازن كريم محمد عبدالحليم
# 544                  1   79528              ابراهيم سامى ابراهيم صليب
# 545                 96   79963               عبير محمد هاشم ابوالعنين
# 546                 96   80692                    محمود صلاح على محمد
# 547                 96   80851                   مروه فريد محمود عباس
# 548                  2   82681                     نسمه جمال محمد على
# 549                 25   82686                      اروى محمد على على
# 550                 25   83192                سيف محمد سمير عبدالرحمن
# 551                  0   84721                 ابتسام ابراهيم على حسن
# 552                  0   84721                 ابتسام ابراهيم على حسن
# 553                 13   85729                     ساره محمد سعد راشد
# 554                  0   86397              احمد محمد عبدالمنعم جنديه
# 555                 96   87167                    يوسف احمد سمير احمد
# 556                 19   88373               عبير عبداللطيف مهدى مرسى
# 557                 25   88433                      فردوس فهمى شاكر .
# 558                 19   88893           عبدالتواب عبدالعاطى على محمد
# 559                  6   89709          سيده ابراهيم محمدين عبدالقادر
# 560                  3   90144                   علاء السيد على عماره
# 561                 25   93734                    محمد احسان احمد زكى
# 562                 34   95424     محمد عبدالعظيم عبدالحليم عبدالرحيم
# 563                 29   95890              عماد عبدالحفيظ احمد عفيفى
# 564                 96   96297                     سيد احمد محمد حسين
# 565                 29   97808                فاطمه سالم عبدالله محمد
# 566                 19   97870              جراتسيا مينا مجدى نابليون
# 567                 25   99486                    ياسين محمد محى محمد
# 568                 25   99514                سمير سالم محمد عبدالعال
# 569                  1   99611                  ايمن محسوب دسوقى بدرى
#
#                                5            6           7             8    9   \
# 0    number of patient admissions  Patient Sex  male count  female count  Age
# 1                               1          ذكر         329           240    4
# 2                               1          ذكر                              6
# 3                               1          ذكر                              3
# 4                               1          ذكر                             32
# 5                               1         انثى                             44
# 6                               1          ذكر                             41
# 7                               1         انثى                             44
# 8                               2          ذكر                             36
# 9                               2          ذكر                             36
# 10                              1          ذكر                             48
# 11                              1          ذكر                             41
# 12                              1         انثى                             36
# 13                              1         انثى                             40
# 14                              1         انثى                             11
# 15                              1          ذكر                             59
# 16                              1         انثى                             49
# 17                              1          ذكر                             67
# 18                              1         انثى                             56
# 19                              1          ذكر                              4
# 20                              1         انثى                             29
# 21                              1         انثى                             36
# 22                              1          ذكر                             35
# 23                              1         انثى                              5
# 24                              1          ذكر                             34
# 25                              1          ذكر                             47
# 26                              1         انثى                             26
# 27                              1          ذكر                             33
# 28                              1          ذكر                             51
# 29                              1         انثى                             31
# ..                            ...          ...         ...           ...  ...
# 540                             1         انثى                              7
# 541                             1          ذكر                              3
# 542                             1         انثى                             35
# 543                             1          ذكر                              3
# 544                             1          ذكر                             33
# 545                             1         انثى                             40
# 546                             1          ذكر                             29
# 547                             1         انثى                             31
# 548                             1         انثى                             27
# 549                             1         انثى                              4
# 550                             1          ذكر                              3
# 551                             2         انثى                             55
# 552                             2         انثى                             55
# 553                             1         انثى                             27
# 554                             1          ذكر                             37
# 555                             1          ذكر                              7
# 556                             1         انثى                             43
# 557                             1         انثى                             65
# 558                             1          ذكر                             54
# 559                             1         انثى                             47
# 560                             1          ذكر                             58
# 561                             1          ذكر                             22
# 562                             1          ذكر                             37
# 563                             1          ذكر                             51
# 564                             1          ذكر                             48
# 565                             1         انثى                             44
# 566                             1         انثى                              4
# 567                             1          ذكر                              7
# 568                             1          ذكر                             39
# 569                             1          ذكر                              9
#
#              ...            39      40            41 42  \
# 0            ...                 592.1   3.222222222
# 1            ...             0   280.9           5.6
# 2            ...             0     535             1
# 3            ...             0   540.9          3.75
# 4            ...             1  474.02          0.25
# 5            ...             0     789           2.4
# 6            ...             2     466             1
# 7            ...             0     565  0.6666666667
# 8            ...             1   280.1             1
# 9            ...             3   410.9       #DIV/0!
# 10           ...             2  575.11             0
# 11           ...             1     750             1
# 12           ...             1     280             1
# 13           ...             0   414.9             5
# 14           ...             1   535.5           0.5
# 15           ...            14   553.1   3.333333333
# 16           ...             1     592       #DIV/0!
# 17           ...             3   669.7             2
# 18           ...             1   682.9
# 19           ...             0   685.1
# 20           ...             0   706.2
# 21           ...             0   710.1
# 22           ...             0  717.83
# 23           ...             0  789.06
# 24           ...             1     6.2
# 25           ...             0   70.54
# 26           ...             2     142
# 27           ...             0   153.9
# 28           ...            11     174
# 29           ...             0  201.58
# ..           ...            ..     ...           ... ..
# 540          ...             0
# 541          ...             3
# 542          ...             4
# 543          ...             0
# 544          ...             0
# 545          ...             0
# 546          ...             0
# 547          ...             1
# 548          ...             1
# 549          ...             0
# 550          ...             4
# 551          ...             9
# 552          ...             1
# 553          ...             0
# 554          ...             5
# 555          ...             1
# 556          ...             0
# 557          ...             5
# 558          ...             3
# 559          ...             1
# 560          ...             7
# 561          ...             0
# 562          ...             0
# 563          ...            12
# 564          ...             2
# 565          ...             0
# 566          ...             0
# 567          ...             0
# 568          ...             3
# 569          ...             0
#
#                                  43                        44           45  \
# 0                  Discharge Status  ranking discharge status     Fin_Type
# 1                          IMPROVED                       512  حالات شركات
# 2                          IMPROVED                       512  حالات شركات
# 3                          IMPROVED                       512  حالات شركات
# 4                          IMPROVED                       512  حالات شركات
# 5                          IMPROVED                       512  حالات شركات
# 6                          IMPROVED                       512  حالات شركات
# 7                          IMPROVED                       512  حالات شركات
# 8                          IMPROVED                       512  حالات شركات
# 9                          IMPROVED                       512  حالات شركات
# 10                         IMPROVED                       512  حالات شركات
# 11                         IMPROVED                       512  حالات شركات
# 12                         IMPROVED                       512  حالات شركات
# 13            RESERVATION CANCELLED                        14  حالات شركات
# 14                         IMPROVED                       512  حالات شركات
# 15                         IMPROVED                       512  حالات شركات
# 16                         IMPROVED                       512   حالات خاصه
# 17                         IMPROVED                       512  حالات شركات
# 18                         IMPROVED                       512   حالات خاصه
# 19                         IMPROVED                       512  حالات شركات
# 20                         IMPROVED                       512   حالات خاصه
# 21                         IMPROVED                       512  حالات شركات
# 22                         IMPROVED                       512  حالات شركات
# 23                         IMPROVED                       512  حالات شركات
# 24                         IMPROVED                       512  حالات شركات
# 25                         IMPROVED                       512  حالات شركات
# 26                         IMPROVED                       512   حالات خاصه
# 27                         IMPROVED                       512  حالات شركات
# 28                         IMPROVED                       512   حالات خاصه
# 29                         IMPROVED                       512  حالات شركات
# ..                              ...                       ...          ...
# 540                        IMPROVED                       512  حالات شركات
# 541                        IMPROVED                       512  حالات شركات
# 542                            DAMA                        32  حالات شركات
# 543                        IMPROVED                       512  حالات شركات
# 544                       MORTALITY                         8  حالات شركات
# 545                        IMPROVED                       512  حالات شركات
# 546                        IMPROVED                       512  حالات شركات
# 547                        IMPROVED                       512  حالات شركات
# 548                        IMPROVED                       512  حالات شركات
# 549                        IMPROVED                       512  حالات شركات
# 550                        IMPROVED                       512  حالات شركات
# 551                        IMPROVED                       512   حالات خاصه
# 552                            DAMA                        32   حالات خاصه
# 553                        IMPROVED                       512  حالات شركات
# 554  TRANSFERED TO ANOTHER FACILITY                         1   حالات خاصه
# 555                            DAMA                        32  حالات شركات
# 556                        IMPROVED                       512  حالات شركات
# 557                        IMPROVED                       512  حالات شركات
# 558                        IMPROVED                       512  حالات شركات
# 559                        IMPROVED                       512  حالات شركات
# 560                        IMPROVED                       512  حالات شركات
# 561                        IMPROVED                       512  حالات شركات
# 562                        IMPROVED                       512  حالات شركات
# 563                        IMPROVED                       512  حالات شركات
# 564                        IMPROVED                       512  حالات شركات
# 565                        IMPROVED                       512  حالات شركات
# 566           RESERVATION CANCELLED                        14  حالات شركات
# 567                        IMPROVED                       512  حالات شركات
# 568                        IMPROVED                       512  حالات شركات
# 569                        IMPROVED                       512  حالات شركات
#
#                   46                         47                     48
# 0    common fin type             Patient Source  common patient source
# 1                419  شركات متعاقده مع المستشفى                    315
# 2                419  شركات متعاقده مع المستشفى                    315
# 3                419  شركات متعاقده مع المستشفى                    315
# 4                419                منطقة السكن                     25
# 5                419  شركات متعاقده مع المستشفى                    315
# 6                419  شركات متعاقده مع المستشفى                    315
# 7                419  شركات متعاقده مع المستشفى                    315
# 8                419  شركات متعاقده مع المستشفى                    315
# 9                419  شركات متعاقده مع المستشفى                    315
# 10               419  شركات متعاقده مع المستشفى                    315
# 11               419         العاملين بالمجموعه                     11
# 12               419  شركات متعاقده مع المستشفى                    315
# 13               419  شركات متعاقده مع المستشفى                    315
# 14               419  شركات متعاقده مع المستشفى                    315
# 15               419        الاقارب او الاصدقاء                     44
# 16               150        الاقارب او الاصدقاء                     44
# 17               419  شركات متعاقده مع المستشفى                    315
# 18               150            اعلان في الشارع                     65
# 19               419           رسائل نصية قصيرة                      5
# 20               150        الاقارب او الاصدقاء                     44
# 21               419  شركات متعاقده مع المستشفى                    315
# 22               419  شركات متعاقده مع المستشفى                    315
# 23               419  شركات متعاقده مع المستشفى                    315
# 24               419  شركات متعاقده مع المستشفى                    315
# 25               419  شركات متعاقده مع المستشفى                    315
# 26               150                       اخري                     21
# 27               419  شركات متعاقده مع المستشفى                    315
# 28               150            اعلان في الشارع                     65
# 29               419  شركات متعاقده مع المستشفى                    315
# ..               ...                        ...                    ...
# 540              419  شركات متعاقده مع المستشفى                    315
# 541              419  شركات متعاقده مع المستشفى                    315
# 542              419  شركات متعاقده مع المستشفى                    315
# 543              419            الطبيب المُعالج                     69
# 544              419  شركات متعاقده مع المستشفى                    315
# 545              419  شركات متعاقده مع المستشفى                    315
# 546              419  شركات متعاقده مع المستشفى                    315
# 547              419  شركات متعاقده مع المستشفى                    315
# 548              419        الاقارب او الاصدقاء                     44
# 549              419  شركات متعاقده مع المستشفى                    315
# 550              419  شركات متعاقده مع المستشفى                    315
# 551              150            الطبيب المُعالج                     69
# 552              150            الطبيب المُعالج                     69
# 553              419                       اخري                     21
# 554              150        الاقارب او الاصدقاء                     44
# 555              419        الاقارب او الاصدقاء                     44
# 556              419  شركات متعاقده مع المستشفى                    315
# 557              419        الاقارب او الاصدقاء                     44
# 558              419  شركات متعاقده مع المستشفى                    315
# 559              419         اعلان على الانترنت                      2
# 560              419            الطبيب المُعالج                     69
# 561              419  شركات متعاقده مع المستشفى                    315
# 562              419        الاقارب او الاصدقاء                     44
# 563              419            الطبيب المُعالج                     69
# 564              419  شركات متعاقده مع المستشفى                    315
# 565              419                       اخري                     21
# 566              419  شركات متعاقده مع المستشفى                    315
# 567              419            المشاركة فى حدث                      1
# 568              419  شركات متعاقده مع المستشفى                    315
# 569              419  شركات متعاقده مع المستشفى                    315
#
# [570 rows x 49 columns]

# %%
# for Example to read Age Column 
Age = df.iloc[:,9]
Age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-eb16ca28fe6c> in <module>()
# ----> 1 Age = df.iloc[:,9]
#       2 Age
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.hist(age, bins=10, rwidth=0.95, color = "r")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-bdbfca2b5554> in <module>()
# ----> 1 plt.hist(age, bins=10, rwidth=0.95, color = "r")
#       2
#
# NameError: name 'age' is not defined

# %%
hist = Age.hist(bins=50)

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d467ad0c-0366-47e4-aed2-b44406bdfe5a" name="files[]" multiple disabled />
#      <output id="result-d467ad0c-0366-47e4-aed2-b44406bdfe5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-292f82be1b7a> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 uploaded = files.upload()
#       4
#       5 for fn in uploaded.keys():
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
#      65   files = _collections.defaultdict(_six.binary_type)
#      66   # Mapping from original filename to filename as saved locally.
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: TypeError: Unable to get property '_uploadFiles' of undefined or null reference
