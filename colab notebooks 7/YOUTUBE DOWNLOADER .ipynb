# %%
#this program was initiated to download DR\Ahmed elsaeed youtube videos
# !pip install pytube # python3

# %%
# !pip install youtube_dl
# Out:
# ...
#      |████████████████████████████████| 1.9MB 5.8MB/s
# ...

# %%
import youtube_dl

youtube_playlist_url = 'https://www.youtube.com/playlist?list=PLT1rvk7Trkw5eWUxZCT-w2USwJxEcw-xb'
destination_folder = './youtube_playlist2/'

ydl_opts = {'outtmpl': destination_folder+'/%(title)s.%(ext)s'}
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download([youtube_playlist_url])
# Out:
# [youtube:tab] PLT1rvk7Trkw5eWUxZCT-w2USwJxEcw-xb: Downloading webpage
# [download] Downloading playlist: CoComelon & Friends Holiday and Christmas Videos for Kids | Little Baby Bum | Go Buster and More!
# [youtube:tab] playlist CoComelon & Friends Holiday and Christmas Videos for Kids | Little Baby Bum | Go Buster and More!: Downloading 19 videos
# [download] Downloading video 1 of 19
# [youtube] qIsM7qScR4U: Downloading webpage
# WARNING: Requested formats are incompatible for merge and will be merged into mkv.
# [download] Destination: ./youtube_playlist2//Ski Song _ CoComelon Nursery Rhymes & Kids Songs.f137.mp4
# [download] 100% of 56.71MiB in 00:01
# [download] Destination: ./youtube_playlist2//Ski Song _ CoComelon Nursery Rhymes & Kids Songs.f251.webm
# [download] 100% of 2.86MiB in 00:00
# [ffmpeg] Merging formats into "./youtube_playlist2//Ski Song _ CoComelon Nursery Rhymes & Kids Songs.mkv"
# ...
