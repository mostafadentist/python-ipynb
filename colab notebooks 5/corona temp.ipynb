# %%
# %%html
# <marquee style='width: 50%; color: GOLD;'><b>CORONA TEMP </b></marquee>
# <marquee style='width: 70%; color: RED;'><b>CORONA TEMP </b></marquee>
# <marquee style='width: 90%; color: BLUE;'><b>CORONA TEMP </b></marquee>
# <marquee style='width: 100%; color: green;'><b>CORONA TEMP</b></marquee>
# Out:
# <marquee style='width: 50%; color: GOLD;'><b>CORONA TEMP </b></marquee>
# <marquee style='width: 70%; color: RED;'><b>CORONA TEMP </b></marquee>
# <marquee style='width: 90%; color: BLUE;'><b>CORONA TEMP </b></marquee>
# <marquee style='width: 100%; color: green;'><b>CORONA TEMP</b></marquee>

# %%
#import files to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-986b0743-f17a-4aeb-96df-6a79bae5976b" name="files[]" multiple disabled />
#      <output id="result-986b0743-f17a-4aeb-96df-6a79bae5976b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid (1).jpeg to covid (1).jpeg

# %%
for fn in uploaded.keys ():
   print('user upload file "{name}" with length {length} bytes'.format(name=fn,length=len(uploaded[fn])))
# Out:
# user upload file "covid (1).jpeg" with length 103490 bytes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import numpy as np

# %%
df = pd.read_excel("Corona Temp.xlsx")

# %%
# %load_ext google.colab.data_table

# %%
df
# Out:
#           Date      Region  Confirmed     Repeat
# 0   2020-03-20        Iran      20610        NaN
# 1   2020-03-20       Italy      53578        NaN
# 2   2020-03-20       Spain      25374        NaN
# 3   2020-03-20       China      81008        NaN
# 4   2020-03-20      France      12612        NaN
# ..         ...         ...        ...        ...
# 327 2020-04-03       Niger         98        NaN
# 328 2020-04-03    Paraguay         92   7.222222
# 329 2020-04-03  Bangladesh         61  15.300000
# 330 2020-04-03        Togo         40        NaN
# 331 2020-04-03        Mali         39        NaN
#
# [332 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Region', 'Confirmed', 'Repeat'], dtype='object')

# %%
x = df.drop(['Confirmed'], axis=1)
x
# Out:
#           Date      Region     Repeat
# 0   2020-03-20        Iran        NaN
# 1   2020-03-20       Italy        NaN
# 2   2020-03-20       Spain        NaN
# 3   2020-03-20       China        NaN
# 4   2020-03-20      France        NaN
# ..         ...         ...        ...
# 327 2020-04-03       Niger        NaN
# 328 2020-04-03    Paraguay   7.222222
# 329 2020-04-03  Bangladesh  15.300000
# 330 2020-04-03        Togo        NaN
# 331 2020-04-03        Mali        NaN
#
# [332 rows x 3 columns]

# %%
# !pip install pivottablejs
from pivottablejs import pivot_ui

# %%
pivot_ui(x)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import IPython
IPython.display.HTML(filename='/content/pivottablejs.html')
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>PivotTable.js</title>
#
#         <!-- external libs from cdnjs -->
#         <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.css">
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.11/c3.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js"></script>
#         <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jquery-csv/0.71/jquery.csv-0.71.min.js"></script>
#
#
# ...

# %%
# !pip install -u dtale
import dtale
import dtale.app as dtale_app
dtale_app.USE_NGROK = True
df3 = pd.read_excel("Corona Temp.xlsx")
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -u

# %%
dtale.show(df3, ignore_duplicate=True)
# Out:
# http://7a2bd16b.ngrok.io/dtale/main/3
