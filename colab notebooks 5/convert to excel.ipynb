# %%
# !unzip -q /content/drive/MyDrive/2013_test.zip

# %%
# !pip install openpyxl

# %%
import pandas as pd
import openpyxl

# %%
df1 = pd.read_csv('/content/2013_test/- National Telecom Re.csv',encoding='latin')

# %%
df1
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ( Policy Id= 121 ,  User Id= 302 ,  Client Id= 114 , Rt Datetime= 22-Feb-19 ,  From Date= 09/09/2013 ,  To Date= 08/10/2019)
# ...

# %%
df1.to_excel(r'/content/sample_data\File Name.xlsx')

# %%
df2 = pd.read_csv('/content/2013_test/- Not insured contract.csv',encoding='latin-1')

# %%
df3 = pd.read_csv('/content/2013_test/- valve & Tools.S.A.E.csv',encoding='latin-1')

# %%
df4 = pd.read_csv('/content/2013_test/1521 - IFFCO.csv',dtype=object, encoding='iso-8859-1')

# %%
writer = pd.ExcelWriter('output4.xlsx')
df1.to_excel(writer)
writer.save()

# %%
df5 = pd.read_csv('/content/2013_test/1608 Metro Market for.csv', encoding='latin-1')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,2,3,4,6,8,12,13,15,16,17,26,27,28,32,33,37,38,39,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df5
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ( Policy Id= 101 ,  User Id= 302 ,  Client Id= 97 , Rt Datetime= 20-Feb-19 ,  From Date= 01/06/2013 ,  To Date= 18/02/2019)
# ...

# %%
df5.to_excel(r'/content/sample_data\File Name.xlsx', index = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-04f9c0ef4850> in <module>()
# ----> 1 df5.to_excel(r'/content/sample_data\File Name.xlsx', index = True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2030             startcol=startcol,
#    2031             freeze_panes=freeze_panes,
# -> 2032             engine=engine,
#    2033         )
#    2034
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     737             startrow=startrow,
#     738             startcol=startcol,
# --> 739             freeze_panes=freeze_panes,
#     740         )
# ...

# %%
df6 = pd.read_csv('/content/2013_test/1649 Egyptian Operating C.csv',encoding='latin-1')

# %%
df7 = pd.read_csv('/content/2013_test/1652 Sidi Krir Management Services.csv',encoding='latin-1')

# %%
df8 = pd.read_csv('/content/2013_test/1654 - Diversey Egypt.csv',encoding='latin-1')

# %%
df9 = pd.read_csv('/content/2013_test/1657 UEICO.csv',encoding='latin-1')
