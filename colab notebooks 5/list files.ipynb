# %%
from os import walk
import pandas as pd
import numpy as np

# %%
f = []
for (dirpath, dirnames, filenames) in walk('/content/list'):
    f.extend(filenames)
    break

# %%
print (f)
# Out:
# ['spssdraiman.xlsx', 'spssdraiman.sav', 'pivottablejs-0.9.0-py2.py3-none-any.whl', 'bman03.pps']

# %%
import os
os.listdir("/content/list")
x = os.listdir("/content/list")

# %%
print (x)
# Out:
# ['spssdraiman.xlsx', 'spssdraiman.sav', 'pivottablejs-0.9.0-py2.py3-none-any.whl', 'bman03.pps']

# %%
type(x)
# Out:
# list

# %%
# Creating a dataframe object from listoftuples
df = pd.DataFrame(x)
print (df)
# Out:
#                                          0
# 0                         spssdraiman.xlsx
# 1                          spssdraiman.sav
# 2  pivottablejs-0.9.0-py2.py3-none-any.whl
# 3                               bman03.pps

# %%
df.to_excel("output.xlsx")

# %%
from google.colab import files
files.download('output.xlsx')
