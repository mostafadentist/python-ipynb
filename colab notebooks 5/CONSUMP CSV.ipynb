# %%
#consump data NOT converted from DTA stata form 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io

# %%
#import files to colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a3296d7-abac-4a34-90b3-7c72f36ac3ea" name="files[]" multiple disabled />
#      <output id="result-5a3296d7-abac-4a34-90b3-7c72f36ac3ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving consump.csv to consump.csv

# %%
for fn in uploaded.keys ():
   print('user upload file "{name}" with length {length} bytes'.format(name=fn,length=len(uploaded[fn])))
# Out:
# user upload file "consump.csv" with length 8252 bytes

# %%
import io

# %%
consump_df = pd.read_csv("consump.csv")

# %%
consump_df
# Out:
#     Unnamed: 0  year     i3   inf  ...      gc_2      gy_2  r3_2   lc_ly_2
# 0            0  1959   3.41   0.7  ...       NaN       NaN   NaN       NaN
# 1            1  1960   2.93   1.7  ...       NaN       NaN   NaN       NaN
# 2            2  1961   2.38   1.0  ...       NaN       NaN  2.71 -0.167827
# 3            3  1962   2.78   1.0  ...  0.013926  0.006959  1.23 -0.160860
# 4            4  1963   3.16   1.3  ...  0.013285  0.015111  1.38 -0.162686
# 5            5  1964   3.55   1.3  ...  0.025081  0.031706  1.78 -0.169312
# 6            6  1965   3.95   1.6  ...  0.019167  0.021446  1.86 -0.171591
# 7            7  1966   4.88   2.9  ...  0.040209  0.055637  2.25 -0.187019
# 8            8  1967   4.32   3.1  ...  0.039308  0.049463  2.35 -0.197175
# 9            9  1968   5.34   4.2  ...  0.039617  0.039280  1.98 -0.196838
# 10          10  1969   6.68   5.5  ...  0.022531  0.031766  1.22 -0.206074
# 11          11  1970   6.46   5.7  ...  0.037767  0.034411  1.14 -0.202718
# 12          12  1971   4.35   4.4  ...  0.028340  0.022510  1.18 -0.196887
# 13          13  1972   4.07   3.2  ...  0.021200  0.026377  0.76 -0.202064
# 14          14  1973   7.04   6.2  ...  0.015693  0.026490 -0.05 -0.212861
# 15          15  1974   7.89  11.0  ...  0.037800  0.033841  0.87 -0.208902
# 16          16  1975   5.84   9.1  ...  0.029625  0.058443  0.84 -0.237720
# 17          17  1976   4.99   5.8  ... -0.003231 -0.016973 -3.11 -0.223978
# 18          18  1977   5.27   6.5  ...  0.016549  0.006860 -3.26 -0.214289
# 19          19  1978   7.22   7.6  ...  0.034577  0.028788 -0.81 -0.208499
# 20          20  1979  10.04  11.3  ...  0.024832  0.021713 -1.23 -0.205380
# 21          21  1980  11.51  13.5  ...  0.030622  0.039372 -0.38 -0.214131
# 22          22  1981  14.03  10.3  ...  0.016846  0.016073 -1.26 -0.213359
# 23          23  1982  10.69   6.2  ... -0.002139 -0.006030 -1.99 -0.209468
# 24          24  1983   8.63   3.2  ...  0.002780  0.013361  3.73 -0.220049
# 25          25  1984   9.58   4.3  ...  0.004149 -0.000763  4.49 -0.215137
# 26          26  1985   7.48   3.6  ...  0.030221  0.018356  5.43 -0.203272
# 27          27  1986   5.98   1.9  ...  0.029409  0.061985  5.28 -0.235847
# 28          28  1987   5.82   3.6  ...  0.030111  0.020976  3.88 -0.226712
# 29          29  1988   6.69   4.1  ...  0.022599  0.022799  4.08 -0.226912
# 30          30  1989   8.12   4.8  ...  0.023979  0.007378  2.22 -0.210311
# 31          31  1990   7.51   5.4  ...  0.026111  0.029631  2.59 -0.213831
# 32          32  1991   5.42   4.2  ...  0.012976  0.010201  3.32 -0.211057
# 33          33  1992   3.45   3.0  ...  0.009540  0.007863  2.11 -0.209380
# 34          34  1993   3.02   3.0  ... -0.009107 -0.010468  1.22 -0.208018
# 35          35  1994   4.29   2.6  ...  0.012775  0.017057  0.45 -0.212300
# 36          36  1995   5.51   2.8  ...  0.011756  0.000879  0.02 -0.201424
#
# [37 rows x 25 columns]
