# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install pyreadstat
# Out:
# ...
#      |████████████████████████████████| 2.0MB 3.4MB/s
# ...

# %%
import pyreadstat

# %%
df = pd.read_spss("/content/Sheet Corona- 4.sav")
df.head(2)
# Out:
#    Serial  ... RoleofNeurosurgeonstoshowsolidarityagainstCoronavirus
# 0     1.0  ...         No role/personal level/Institutional level
# 1     2.0  ...              Organizational/National/International
#
# [2 rows x 21 columns]

# %%
list(df.columns)
# Out:
# ['Serial',
#  'Specialty',
#  'IncomelevelWB',
#  'Region',
#  'Yearsofexperience',
#  'Practicesetting',
#  'CaseloadofCOVID19',
#  'PerceptionaboutseriousnessofCOVID19',
#  'SourceofCOVIDinfo',
#  'Hospitalpreparedness',
#  'Privatepracticeproviders',
#  'Government_Hospitalproviders',
#  'Reasonforcanceling',
#  'Methodforcancelation',
#  'PricesofORsupplies',
#  'PPEutilized',
#  'FinancialBurdentoProvider',
#  'ChangetoProviderWorkload',
#  'ChangetoScientific_EducationalActivities',
#  'ChangetoResearchActivities',
#  'RoleofNeurosurgeonstoshowsolidarityagainstCoronavirus']

# %%
feature_cols = ['Specialty', 'IncomelevelWB', 'Region','Yearsofexperience', 'Practicesetting','CaseloadofCOVID19','PerceptionaboutseriousnessofCOVID19','SourceofCOVIDinfo','Hospitalpreparedness','Privatepracticeproviders','Government_Hospitalproviders','Reasonforcanceling','Methodforcancelation','PricesofORsupplies','PPEutilized','FinancialBurdentoProvider','ChangetoProviderWorkload','ChangetoScientific_EducationalActivities','ChangetoResearchActivities','RoleofNeurosurgeonstoshowsolidarityagainstCoronavirus' ]
X = df[feature_cols] # Features
