# %% [markdown]
# # 02. Predict Employee Attrition

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Install all related packages. If you find additional packages missing, please follow the same technique.
#If you are not using anaconda, then use pip to install the same packages

import sys
# !conda install --yes --prefix {sys.prefix} pandas tensorflow
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/hr
#
#   added / updated specs:
#     - pandas
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-1.0.4               |   py37h959d312_0         7.9 MB
#     ------------------------------------------------------------
#                                            Total:         7.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   _tflow_select      pkgs/main/osx-64::_tflow_select-2.3.0-mkl
#   absl-py            pkgs/main/osx-64::absl-py-0.9.0-py37_0
#   astor              pkgs/main/osx-64::astor-0.8.0-py37_0
#   blas               pkgs/main/osx-64::blas-1.0-mkl
#   c-ares             pkgs/main/osx-64::c-ares-1.15.0-h1de35cc_1001
#   gast               pkgs/main/osx-64::gast-0.2.2-py37_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-py_0
#   grpcio             pkgs/main/osx-64::grpcio-1.16.1-py37h044775b_1
#   h5py               pkgs/main/osx-64::h5py-2.10.0-py37h3134771_0
#   hdf5               pkgs/main/osx-64::hdf5-1.10.4-hfa1e0ec_0
#   intel-openmp       pkgs/main/osx-64::intel-openmp-2019.4-233
#   keras-applications pkgs/main/noarch::keras-applications-1.0.8-py_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.0-py_1
#   libgfortran        pkgs/main/osx-64::libgfortran-3.0.1-h93005f0_2
#   libprotobuf        pkgs/main/osx-64::libprotobuf-3.12.3-hab81aa3_0
#   markdown           pkgs/main/osx-64::markdown-3.1.1-py37_0
#   mkl                pkgs/main/osx-64::mkl-2019.4-233
#   mkl-service        pkgs/main/osx-64::mkl-service-2.3.0-py37hfbe908c_0
#   mkl_fft            pkgs/main/osx-64::mkl_fft-1.0.15-py37h5e564d8_0
#   mkl_random         pkgs/main/osx-64::mkl_random-1.1.1-py37h959d312_0
#   numpy              pkgs/main/osx-64::numpy-1.18.1-py37h7241aed_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.18.1-py37h3304bdc_1
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.1.0-py_0
#   pandas             pkgs/main/osx-64::pandas-1.0.4-py37h959d312_0
#   protobuf           pkgs/main/osx-64::protobuf-3.12.3-py37hb1e8313_0
#   pytz               pkgs/main/noarch::pytz-2020.1-py_0
#   scipy              pkgs/main/osx-64::scipy-1.4.1-py37h9fa6033_0
#   tensorboard        pkgs/main/noarch::tensorboard-2.0.0-pyhb38c66f_1
#   tensorflow         pkgs/main/osx-64::tensorflow-2.0.0-mkl_py37hda344b4_0
#   tensorflow-base    pkgs/main/osx-64::tensorflow-base-2.0.0-mkl_py37h66b1bf0_0
#   tensorflow-estima~ pkgs/main/noarch::tensorflow-estimator-2.0.0-pyh2649769_0
#   termcolor          pkgs/main/osx-64::termcolor-1.1.0-py37_1
#   werkzeug           pkgs/main/noarch::werkzeug-1.0.1-py_0
#   wrapt              pkgs/main/osx-64::wrapt-1.12.1-py37h1de35cc_1
#
#
#
# Downloading and Extracting Packages
# pandas-1.0.4         | 7.9 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## 02.04. Preprocessing Attrition Data

# %%
#Load the dataset and analyze

import pandas as pd
import os
import tensorflow as tf
import numpy as np

attrition_data = pd.read_csv("/content/drive/MyDrive/Ai in HR/employee_attrition.csv")

print("Data Loaded:\n------------------------\n",attrition_data.dtypes)
attrition_data.head()
# Out:
# Data Loaded:
# ------------------------
#  EmployeeID              int64
# TotalMonthsOfExp        int64
# TotalOrgsWorked         int64
# MonthsInOrg             int64
# LastPayIncrementBand    int64
# AverageFeedback         int64
# LastPromotionYears      int64
# Attrition               int64
# dtype: object
#    EmployeeID  TotalMonthsOfExp  ...  LastPromotionYears  Attrition
# 0           1               110  ...                   4          1
# 1           2               103  ...                   2          0
# 2           3                41  ...                   4          1
# 3           4                32  ...                   3          0
# 4           5                80  ...                   2          0
#
# [5 rows x 8 columns]

# %%
#Correlation Analysis of target attribute

attrition_data.corr()['Attrition']
# Out:
# EmployeeID             -0.036630
# TotalMonthsOfExp        0.019702
# TotalOrgsWorked         0.008706
# MonthsInOrg             0.012605
# LastPayIncrementBand    0.108528
# AverageFeedback        -0.008253
# LastPromotionYears      0.765641
# Attrition               1.000000
# Name: Attrition, dtype: float64

# %%
#Convert to Dataframe to numpy array
np_attrition = attrition_data.to_numpy().astype(float)

#Create X_train with the first 7 attributes
X_train = np_attrition[:,1:7]
#Create Y_train with attrition attribute
Y_train=np_attrition[:,7]

#Convert Y_train to one-hot-encoding
Y_train = tf.keras.utils.to_categorical(Y_train,2)

print("X-Train Shape : ", X_train.shape)
print("Y-Train Shape : ", Y_train.shape)
# Out:
# X-Train Shape :  (1000, 6)
# Y-Train Shape :  (1000, 2)

# %% [markdown]
# ## 02.05. Build Attrition model with Keras

# %%
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.regularizers import l2

#Setup hyperparameters for deep learning
EPOCHS=100
BATCH_SIZE=100
VERBOSE=1
NB_CLASSES=2
N_HIDDEN=128
VALIDATION_SPLIT=0.2

#Create a Keras model
model = tf.keras.models.Sequential()

#Add first hidden Dense layer
model.add(keras.layers.Dense(N_HIDDEN,
                             input_shape=(6,),
                              name='Dense-Layer-1',
                              activation='relu'))

#Add a second hidden dense layer
model.add(keras.layers.Dense(N_HIDDEN,
                              name='Dense-Layer-2',
                              activation='relu'))

#Add a final layer with softmax
model.add(keras.layers.Dense(NB_CLASSES,
                             name='Final',
                             activation='softmax'))

#Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#Fit parameters 
model.fit(X_train,
          Y_train,
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          verbose=VERBOSE,
          validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 29ms/step - loss: 1.8922 - accuracy: 0.6162 - val_loss: 1.7289 - val_accuracy: 0.7850
# Epoch 2/100
# 8/8 [==============================] - 0s 5ms/step - loss: 1.2510 - accuracy: 0.7088 - val_loss: 1.1717 - val_accuracy: 0.2750
# Epoch 3/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8016 - accuracy: 0.6562 - val_loss: 0.6613 - val_accuracy: 0.7850
# Epoch 4/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5840 - accuracy: 0.7638 - val_loss: 0.5624 - val_accuracy: 0.7750
# Epoch 5/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5138 - accuracy: 0.7925 - val_loss: 0.5140 - val_accuracy: 0.7700
# Epoch 6/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4788 - accuracy: 0.7850 - val_loss: 0.4883 - val_accuracy: 0.7750
# Epoch 7/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4631 - accuracy: 0.7950 - val_loss: 0.4695 - val_accuracy: 0.7800
# Epoch 8/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4391 - accuracy: 0.8037 - val_loss: 0.4967 - val_accuracy: 0.7750
# Epoch 9/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4667 - accuracy: 0.7925 - val_loss: 0.4234 - val_accuracy: 0.8400
# Epoch 10/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4370 - accuracy: 0.8087 - val_loss: 0.4256 - val_accuracy: 0.8350
# Epoch 11/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4052 - accuracy: 0.8250 - val_loss: 0.4103 - val_accuracy: 0.8100
# Epoch 12/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3845 - accuracy: 0.8400 - val_loss: 0.3877 - val_accuracy: 0.8250
# Epoch 13/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3785 - accuracy: 0.8300 - val_loss: 0.3957 - val_accuracy: 0.8150
# Epoch 14/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3757 - accuracy: 0.8350 - val_loss: 0.3781 - val_accuracy: 0.8600
# Epoch 15/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3840 - accuracy: 0.8325 - val_loss: 0.4603 - val_accuracy: 0.7900
# Epoch 16/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3955 - accuracy: 0.8325 - val_loss: 0.3754 - val_accuracy: 0.8300
# Epoch 17/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3479 - accuracy: 0.8425 - val_loss: 0.3492 - val_accuracy: 0.8500
# Epoch 18/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3346 - accuracy: 0.8600 - val_loss: 0.3343 - val_accuracy: 0.8650
# Epoch 19/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3323 - accuracy: 0.8662 - val_loss: 0.3371 - val_accuracy: 0.8500
# Epoch 20/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3330 - accuracy: 0.8487 - val_loss: 0.3239 - val_accuracy: 0.8550
# Epoch 21/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3162 - accuracy: 0.8750 - val_loss: 0.3570 - val_accuracy: 0.8300
# Epoch 22/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3210 - accuracy: 0.8512 - val_loss: 0.3164 - val_accuracy: 0.8650
# Epoch 23/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2970 - accuracy: 0.8737 - val_loss: 0.3129 - val_accuracy: 0.8850
# Epoch 24/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2988 - accuracy: 0.8712 - val_loss: 0.3328 - val_accuracy: 0.8350
# Epoch 25/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3012 - accuracy: 0.8650 - val_loss: 0.2963 - val_accuracy: 0.8900
# Epoch 26/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2992 - accuracy: 0.8750 - val_loss: 0.2929 - val_accuracy: 0.8700
# Epoch 27/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2661 - accuracy: 0.8975 - val_loss: 0.2999 - val_accuracy: 0.8550
# Epoch 28/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2675 - accuracy: 0.8863 - val_loss: 0.3066 - val_accuracy: 0.8600
# Epoch 29/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2727 - accuracy: 0.8750 - val_loss: 0.3351 - val_accuracy: 0.8550
# Epoch 30/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2712 - accuracy: 0.8700 - val_loss: 0.2662 - val_accuracy: 0.8900
# Epoch 31/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2892 - accuracy: 0.8875 - val_loss: 0.2596 - val_accuracy: 0.9200
# Epoch 32/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2631 - accuracy: 0.8813 - val_loss: 0.3656 - val_accuracy: 0.8300
# Epoch 33/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2620 - accuracy: 0.8875 - val_loss: 0.2499 - val_accuracy: 0.9050
# Epoch 34/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2576 - accuracy: 0.8875 - val_loss: 0.2681 - val_accuracy: 0.8750
# Epoch 35/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2346 - accuracy: 0.9112 - val_loss: 0.2940 - val_accuracy: 0.8600
# Epoch 36/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2917 - accuracy: 0.8700 - val_loss: 0.3004 - val_accuracy: 0.8600
# Epoch 37/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3119 - accuracy: 0.8625 - val_loss: 0.2863 - val_accuracy: 0.8800
# Epoch 38/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3293 - accuracy: 0.8662 - val_loss: 0.4264 - val_accuracy: 0.7850
# Epoch 39/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3138 - accuracy: 0.8650 - val_loss: 0.3393 - val_accuracy: 0.8150
# Epoch 40/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2446 - accuracy: 0.8963 - val_loss: 0.2282 - val_accuracy: 0.9200
# Epoch 41/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2157 - accuracy: 0.9000 - val_loss: 0.2141 - val_accuracy: 0.9250
# Epoch 42/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2191 - accuracy: 0.9025 - val_loss: 0.2564 - val_accuracy: 0.9050
# Epoch 43/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2231 - accuracy: 0.9013 - val_loss: 0.3187 - val_accuracy: 0.8350
# Epoch 44/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.2798 - accuracy: 0.8712 - val_loss: 0.2322 - val_accuracy: 0.9100
# Epoch 45/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2485 - accuracy: 0.8888 - val_loss: 0.2967 - val_accuracy: 0.8650
# Epoch 46/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2210 - accuracy: 0.9087 - val_loss: 0.2385 - val_accuracy: 0.8850
# Epoch 47/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1932 - accuracy: 0.9175 - val_loss: 0.2474 - val_accuracy: 0.8700
# Epoch 48/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1938 - accuracy: 0.9225 - val_loss: 0.1907 - val_accuracy: 0.9350
# Epoch 49/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1884 - accuracy: 0.9150 - val_loss: 0.2004 - val_accuracy: 0.9100
# Epoch 50/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1824 - accuracy: 0.9337 - val_loss: 0.2009 - val_accuracy: 0.9300
# Epoch 51/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1806 - accuracy: 0.9250 - val_loss: 0.1943 - val_accuracy: 0.9350
# Epoch 52/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1847 - accuracy: 0.9262 - val_loss: 0.2493 - val_accuracy: 0.8850
# Epoch 53/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1946 - accuracy: 0.9150 - val_loss: 0.1857 - val_accuracy: 0.9300
# Epoch 54/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1833 - accuracy: 0.9200 - val_loss: 0.1759 - val_accuracy: 0.9400
# Epoch 55/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1931 - accuracy: 0.9162 - val_loss: 0.2510 - val_accuracy: 0.8700
# Epoch 56/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2187 - accuracy: 0.9100 - val_loss: 0.1983 - val_accuracy: 0.9150
# Epoch 57/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1668 - accuracy: 0.9438 - val_loss: 0.1890 - val_accuracy: 0.9250
# Epoch 58/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1652 - accuracy: 0.9350 - val_loss: 0.1887 - val_accuracy: 0.9100
# Epoch 59/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1534 - accuracy: 0.9375 - val_loss: 0.1758 - val_accuracy: 0.9200
# Epoch 60/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1530 - accuracy: 0.9400 - val_loss: 0.1918 - val_accuracy: 0.9200
# Epoch 61/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1417 - accuracy: 0.9513 - val_loss: 0.1594 - val_accuracy: 0.9450
# Epoch 62/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1544 - accuracy: 0.9375 - val_loss: 0.2647 - val_accuracy: 0.8600
# Epoch 63/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.2135 - accuracy: 0.9025 - val_loss: 0.1715 - val_accuracy: 0.9150
# Epoch 64/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1800 - accuracy: 0.9250 - val_loss: 0.1632 - val_accuracy: 0.9400
# Epoch 65/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1614 - accuracy: 0.9375 - val_loss: 0.2552 - val_accuracy: 0.8700
# Epoch 66/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1710 - accuracy: 0.9312 - val_loss: 0.2683 - val_accuracy: 0.8650
# Epoch 67/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2425 - accuracy: 0.8913 - val_loss: 0.2123 - val_accuracy: 0.9100
# Epoch 68/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2557 - accuracy: 0.8938 - val_loss: 0.2758 - val_accuracy: 0.8550
# Epoch 69/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1661 - accuracy: 0.9250 - val_loss: 0.1749 - val_accuracy: 0.9400
# Epoch 70/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1368 - accuracy: 0.9550 - val_loss: 0.1473 - val_accuracy: 0.9500
# Epoch 71/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9300 - val_loss: 0.2136 - val_accuracy: 0.8800
# Epoch 72/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1579 - accuracy: 0.9438 - val_loss: 0.1964 - val_accuracy: 0.9200
# Epoch 73/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1528 - accuracy: 0.9337 - val_loss: 0.1773 - val_accuracy: 0.9200
# Epoch 74/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1437 - accuracy: 0.9400 - val_loss: 0.1381 - val_accuracy: 0.9550
# Epoch 75/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1393 - accuracy: 0.9350 - val_loss: 0.2576 - val_accuracy: 0.8750
# Epoch 76/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1468 - accuracy: 0.9375 - val_loss: 0.1494 - val_accuracy: 0.9150
# Epoch 77/100
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1327 - accuracy: 0.9500 - val_loss: 0.1576 - val_accuracy: 0.9400
# Epoch 78/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1277 - accuracy: 0.9500 - val_loss: 0.1281 - val_accuracy: 0.9400
# Epoch 79/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 0.9425 - val_loss: 0.2641 - val_accuracy: 0.8650
# Epoch 80/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2033 - accuracy: 0.9050 - val_loss: 0.1612 - val_accuracy: 0.9200
# Epoch 81/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2041 - accuracy: 0.9100 - val_loss: 0.1564 - val_accuracy: 0.9350
# Epoch 82/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1421 - accuracy: 0.9413 - val_loss: 0.1434 - val_accuracy: 0.9500
# Epoch 83/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1196 - accuracy: 0.9575 - val_loss: 0.1521 - val_accuracy: 0.9400
# Epoch 84/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1248 - accuracy: 0.9563 - val_loss: 0.1263 - val_accuracy: 0.9550
# Epoch 85/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1173 - accuracy: 0.9575 - val_loss: 0.1180 - val_accuracy: 0.9500
# Epoch 86/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1135 - accuracy: 0.9650 - val_loss: 0.1656 - val_accuracy: 0.9200
# Epoch 87/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1166 - accuracy: 0.9588 - val_loss: 0.1447 - val_accuracy: 0.9350
# Epoch 88/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1013 - accuracy: 0.9675 - val_loss: 0.1146 - val_accuracy: 0.9550
# Epoch 89/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1057 - accuracy: 0.9650 - val_loss: 0.1120 - val_accuracy: 0.9500
# Epoch 90/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0947 - accuracy: 0.9675 - val_loss: 0.1179 - val_accuracy: 0.9550
# Epoch 91/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1009 - accuracy: 0.9725 - val_loss: 0.1474 - val_accuracy: 0.9350
# Epoch 92/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9600 - val_loss: 0.1007 - val_accuracy: 0.9650
# Epoch 93/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1195 - accuracy: 0.9575 - val_loss: 0.1121 - val_accuracy: 0.9550
# Epoch 94/100
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0857 - accuracy: 0.9762 - val_loss: 0.1078 - val_accuracy: 0.9500
# Epoch 95/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0847 - accuracy: 0.9812 - val_loss: 0.1093 - val_accuracy: 0.9500
# Epoch 96/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0932 - accuracy: 0.9750 - val_loss: 0.1278 - val_accuracy: 0.9500
# Epoch 97/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0805 - accuracy: 0.9837 - val_loss: 0.1021 - val_accuracy: 0.9600
# Epoch 98/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0734 - accuracy: 0.9875 - val_loss: 0.1024 - val_accuracy: 0.9650
# Epoch 99/100
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0762 - accuracy: 0.9887 - val_loss: 0.1191 - val_accuracy: 0.9550
# Epoch 100/100
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1025 - accuracy: 0.9600 - val_loss: 0.1619 - val_accuracy: 0.9200

# %% [markdown]
# ## 02.06. Predict Attrition with Keras

# %%
TotalMonthsOfExp=40
TotalOrgsWorked=4
MonthsInOrg=20
LastPayIncrementBand=5
AverageFeedback=4
LastPromotionYears=4

print("Will employee leave ?", model.predict_classes([[TotalMonthsOfExp,
                                  TotalOrgsWorked,
                                  MonthsInOrg,
                                  LastPayIncrementBand,
                                  AverageFeedback,
                                  LastPromotionYears]]))
# Out:
# Will employee leave ? [1]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
#Bulk predictions

print(model.predict_classes(
    [[111,5,85,3,2,2],
    [31,2,15,4,1,4],
    [61,4,24,1,4,3],
    [77,4,35,3,1,1],
    [81,5,7,1,2,3],
    [113,4,112,5,4,1],
    [101,2,48,5,1,4],
    [45,4,22,5,3,1],
    [25,2,2,2,3,2],
    [97,3,15,3,2,4]]))
# Out:
# [0 1 0 0 0 0 1 0 0 1]
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
