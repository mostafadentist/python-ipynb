# %%
# %%html
# <marquee style='width: 50%; color: GOLD;'><b>correlogram </b></marquee>
# <marquee style='width: 70%; color: RED;'><b>correlogram </b></marquee>
# <marquee style='width: 90%; color: BLUE;'><b>correlogram </b></marquee>
# <marquee style='width: 100%; color: green;'><b>correlogram </b></marquee>
# Out:
# <marquee style='width: 50%; color: GOLD;'><b>correlogram </b></marquee>
# <marquee style='width: 70%; color: RED;'><b>correlogram </b></marquee>
# <marquee style='width: 90%; color: BLUE;'><b>correlogram </b></marquee>
# <marquee style='width: 100%; color: green;'><b>correlogram </b></marquee>

# %%
#import needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import numpy as np

# %%
#import files to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b6282dac-28a6-459a-b2ef-8a941e13c5cc" name="files[]" multiple disabled />
#      <output id="result-b6282dac-28a6-459a-b2ef-8a941e13c5cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving correlogram.csv to correlogram.csv

# %%
for fn in uploaded.keys ():
   print('user upload file "{name}" with length {length} bytes'.format(name=fn,length=len(uploaded[fn])))
# Out:
# user upload file "correlogram.csv" with length 307 bytes

# %%
import io

# %%
cor_df = pd.read_csv("correlogram.csv")

# %%
cor_df
# Out:
#     mo  sales
# 0    1    200
# 1    2    230
# 2    3    220
# 3    4    220
# 4    5    220
# 5    6    220
# 6    7    220
# 7    8    220
# 8    9    270
# 9   10     22
# 10  11     30
# 11  12     50
# 12   1    700
# 13   2    200
# 14   3    500
# 15   4    300
# 16   5    350
# 17   6    350
# 18   7    250
# 19   8    250
# 20   9    250
# 21  10    250
# 22  11    250
# 23  12    250
# 24   1    250
# 25   2    250
# 26   3    250
# 27   4    250
# 28   5    250
# 29   6    250
# 30   7    250
# 31   8    250
# 32   9    250
# 33  10    250
# 34  11    250
# 35  12    250
# 36   1    250
# 37   2    250
# 38   3    250
# 39   4    250
# 40   5    250
# 41   6    250
# 42   7    250
# 43   8    250
# 44   9    250
# 45  10    250
# 46  11    250
# 47  12    250

# %%
import matplotlib.pyplot as plot
import bokeh
import seaborn
import numpy as np

# %%
VARIABLE_1= cor_df['mo'].to_numpy()

# %%
VARIABLE_2= cor_df['sales'].to_numpy()

# %%
plot.hist(VARIABLE_2)
# Out:
# (array([ 3.,  0.,  8., 32.,  3.,  0.,  0.,  1.,  0.,  1.]),
#  array([ 22. ,  89.8, 157.6, 225.4, 293.2, 361. , 428.8, 496.6, 564.4,
#         632.2, 700. ]),
#  <a list of 10 Patch objects>)

# %%
from pandas import read_csv
from matplotlib import pyplot
series = pd.read_csv('correlogram.csv', header=0, index_col=0)
series.plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = pd.read_csv('correlogram.csv', header=0, index_col=0)
plot_acf(series)
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf
series = pd.read_csv('correlogram.csv', header=0, index_col=0)
plot_pacf(series, lags=10)
pyplot.show()
